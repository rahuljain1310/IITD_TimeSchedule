# %%
import requests
import lxml.html as lh
import os
import numpy as np

# %%
course_list = os.listdir(os.getcwd()+'\\project\\course_links');
course_list = [c[:-4] for c in course_list]

# %%
prof_course = []
prof_list = []
student_course = []
student_list = set()
courses_list = []

# %%
i = 0
for course in course_list:
    i+=1
    courses_list.append((i,course))
    page = open('project/course_links/'+course+'.htm','r')
    x = page.read()
    doc = lh.fromstring(x)
    tr_elements = doc.xpath('//tr')
    prof = []
    for t in tr_elements[1]:
        name=t.text_content()
        prof.append(name)
    #finding profID
    j = i
    prof_p = 0
    for c in prof_list:
        if (c[2]==prof[0]):
            prof_p = 1
            j = c[0]
            break
    prof_course.append((j,i))
    if (prof_p==0):
        prof_list.append((j,prof[1],prof[0]))
    for p in range(2,len(tr_elements)):
        T=tr_elements[p]
        if len(T)!=2:
            break
        q = []
        for t in T.iterchildren():
            data=t.text_content()
            q.append(data)
        q = tuple(q)
        student_list.add(q)
        student_course.append((i,q[0]))
    page.close()

# %% [markdown]
# i+=1
# courses_list.append((i,'MTQ301'))
# i+=1
# courses_list.append((i,'MTQ302'))
# i+=1
# courses_list.append((i,'MTQ303'))

# %%
import csv
with open("ProfessorCourses.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(prof_course)
with open("ProfessorList.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(prof_list)
with open("StudentCourses.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(student_course)
with open("StudentList.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(student_list)
with open("CoursesList.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(courses_list)

# %% [markdown]
# import PyPDF2
# pdf1 = open('project/CourseDescription.pdf','rb')
# pdfReader = PyPDF2.PdfFileReader(pdf1)
# num_pages = pdfReader.numPages
# count = 0
# text = ""
# while count < 5:
#     pageObj = pdfReader.getPage(count)
#     text += pageObj.extractText()
#     count+=1
# pdf1.close()

# %% [markdown]
# os.listdir(os.getcwd()+'\\project')

# %%
import csv 
filename = "Courses_Offered.csv"
fields = [] 
rows = [] 
with open(filename, 'r') as csvfile: 
    csvreader = csv.reader(csvfile)  
    for row in csvreader: 
        rows.append(row) 
    print("Total no. of rows: %d"%(csvreader.line_num))
rows = rows[4:]
header = rows[0]
# Out:
# Total no. of rows: 926

# %%
entry = []
i = 1
for c in rows:
    x = c[0]
    try:
        x = int(x)
        if (int(c[0])==i):
            entry.append(c)
            i+=1
    except:
        pass

# %%
## Adding LTP values to the end of row
for row in entry:
    t = row[4].split('-')
    t = [float(c) for c in t]
    row.insert(5,t[0])
    row.insert(6,t[1])
    row.insert(7,t[2])
    t = t[0]+t[1]+t[2]/2
    row[4] = t

# %%
## Seperating name and Course Code
for row in entry:
    t = row[1].split('-')
    name = ""
    for i in range(0,len(t)-1):
        name+=t[i]+" "
    course = t[-1]
    row[1] = name
    row[2] = course

# %%
del entry[611:614]

# %%
import csv
with open("Courses_Offered_Edit2.csv","w+",newline='') as my_csv:
    csvWriter = csv.writer(my_csv,delimiter='$')
    csvWriter.writerows(entry)

# %%
# selection = np.array([True, True, False, True, True, False, True, True, False, False, False, False, False, True, True])
# x = x.transpose
# x[:,selection]

# %%
entry
# Out:
# [['1',
#   'MINI PROJECT (AM)                                  ',
#   'AMD310',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'VIKRANT TIWARI   ',
#   'tiwariv@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '7'],
#  ['2',
#   'MAJOR PROJECT PART I                               ',
#   'AMD811',
#   'P',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'ARGHYA SAMANTA   ',
#   'arghya@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '0'],
#  ['3',
#   'MAJOR PROJECT PART II                              ',
#   'AMD812',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'ARGHYA SAMANTA   ',
#   'arghya@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '31'],
#  ['4',
#   'MAJOR PROJECT PART I                               ',
#   'AMD813',
#   'P',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'ARGHYA SAMANTA   ',
#   'arghya@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '1'],
#  ['5',
#   'MAJOR PROJECT PART II                              ',
#   'AMD814',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'ARGHYA SAMANTA   ',
#   'arghya@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '4'],
#  ['6',
#   'MAJOR PROJECT                                      ',
#   'AMD895',
#   'P',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   '',
#   'AJEET KUMAR   ',
#   'ajeetk@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '2'],
#  ['7',
#   'MINOR PROJECT                                      ',
#   'AMD897',
#   'X',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   '',
#   'SHASHANK SHANKAR   ',
#   'shashankrv@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '25'],
#  ['8',
#   'APPLIED COMPUTATIONAL METHOD                       ',
#   'AML702',
#   'F',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'VAMSI KRISHNA CHALAMALLA ',
#   'vchalama@am.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '100',
#   '36'],
#  ['9',
#   'FINITE ELEMENT METHODS & ITS APPL.TO MARINE STRU.  ',
#   'AML706',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SRIRAM HEGDE   ',
#   'hegde@cc.iitd.ernet.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '100',
#   '32'],
#  ['10',
#   'APPLIED ELASTICITY                                 ',
#   'AML731',
#   'X',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   '',
#   'GAURAV SINGH   ',
#   'gsingh@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '9'],
#  ['11',
#   'SHIP DYNAMICS                                      ',
#   'AML793',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MP MATHEW   ',
#   'mpmathew@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '25'],
#  ['12',
#   'SUBMARINE DESIGN                                   ',
#   'AML795',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SHASHANK SHANKAR   ',
#   'shashankrv@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '25'],
#  ['13',
#   'THEORY OF PLATES AND SHELLS                        ',
#   'AML831',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'BADRI PRASAD PATEL   ',
#   'bppatel@am.iitd.ernet.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '50',
#   '21'],
#  ['14',
#   'APPLICATIONS OF THEORY OF PLATES AND SHELLS        ',
#   'AML832',
#   'A',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   '',
#   'SUSHMA SANTAPURI   ',
#   'ssantapuri@am.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '50',
#   '29'],
#  ['15',
#   'MECHANICS OF COMPOSITE MATERIALS                   ',
#   'AML835',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PUNEET MAHAJAN   ',
#   'mahajan@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '40',
#   '20'],
#  ['16',
#   'PRODUCT DESIGN PROJECT 1                           ',
#   'AMP776',
#   'F',
#   4.0,
#   2.0,
#   0.0,
#   4.0,
#   '',
#   'S.N. SINGH   ',
#   'sns@am.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '20'],
#  ['17',
#   'ENGINEERING MECHANICS                              ',
#   'APL100',
#   'A',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   '',
#   'MALOY KUMAR SINGHA   ',
#   'maloy@am.iitd.ernet.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '250',
#   '469'],
#  ['18',
#   'INTR.TO MATERIAL SC. & ENGG.                       ',
#   'APL102',
#   'E',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'RAJESH PRASAD   ',
#   'rajesh@am.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '300',
#   '131'],
#  ['19',
#   'MECHANICS OF SOLIDS AND FLUIDS                     ',
#   'APL105',
#   'A',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   '',
#   'ANURAG GUPTA   ',
#   'ag@am.iitd.ac.in',
#   'MTh 08:00-09:30',
#   'MTThF 13:00-14:00',
#   '',
#   '150',
#   '122'],
#  ['20',
#   'COMPUTATIONAL MECHANICS                            ',
#   'APL300',
#   'A',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'AJEET KUMAR   ',
#   'ajeetk@am.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '100',
#   '31'],
#  ['21',
#   'FINITE ELEMENT METHOD                              ',
#   'APL705',
#   'B',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'S. PRADYUMNA   ',
#   'pradyum@am.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '100',
#   '53'],
#  ['22',
#   'ADVANCED FLUID MECHANICS                           ',
#   'APL711',
#   'C',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ANUPAM DEWAN   ',
#   'adewan@am.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '50',
#   '12'],
#  ['23',
#   'TURBULENCE AND ITS MODELING                        ',
#   'APL713',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SAWAN SUMAN SINHA   ',
#   'sawan@am.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '50',
#   '20'],
#  ['24',
#   'COMPUTATIONAL FLUID DYNAMICS                       ',
#   'APL720',
#   'E',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'ARJUN SHARMA   ',
#   'arjunsharma@am.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '50',
#   '22'],
#  ['25',
#   'MODERN ENGINEERING MATERIALS                       ',
#   'APL750',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SURESH NEELAKANTAN   ',
#   'sureshn@am.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '50',
#   '13'],
#  ['26',
#   'ENGG. FAILURE ANALYSIS & PREV.                     ',
#   'APL767',
#   'AC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'NITYA NAND GOSVAMI   ',
#   'ngosvami@am.iitd.ac.in',
#   'TF 14:00-15:30',
#   '',
#   '',
#   '40',
#   '15'],
#  ['27',
#   'MODELING AND ANALYSIS                              ',
#   'APL774',
#   'AA',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MURALI RAMAN CHOLEMARI   ',
#   'murali@am.iitd.ac.in',
#   'MTh 14:00-15:30',
#   '',
#   '',
#   '40',
#   '9'],
#  ['28',
#   'ADVANCED SOLID MECHANICS                           ',
#   'APL796',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SITIKANTHA ROY   ',
#   'sroy@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '50',
#   '19'],
#  ['29',
#   'PRODUCT RELIABILITY & MAINTENANCE                  ',
#   'APL871',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SUHAIL  AHMAD ',
#   'suhail@am.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '33'],
#  ['30',
#   'MAJOR PROJECT PART 1 (BB1)                         ',
#   'BBD451',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'RAVI KRISHNAN ELANGOVAN   ',
#   'elangovan@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '4'],
#  ['31',
#   'MAJOR PROJECT PART 2 (BB1)                         ',
#   'BBD452',
#   'Q',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   '',
#   'RAVI KRISHNAN ELANGOVAN   ',
#   'elangovan@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '0'],
#  ['32',
#   'MAJOR PROJECT PART 1 (BB5)                         ',
#   'BBD851',
#   'Q',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'ASHISH MISRA   ',
#   'ashishmisra@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '0'],
#  ['33',
#   'MAJOR PROJECT PART 2 (BB5)                         ',
#   'BBD852',
#   'Q',
#   14.0,
#   0.0,
#   0.0,
#   28.0,
#   '',
#   'ASHISH MISRA   ',
#   'ashishmisra@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '5'],
#  ['34',
#   'MAJOR PROJECT PART 1 (BB5)                         ',
#   'BBD853',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   '',
#   'ASHISH MISRA   ',
#   'ashishmisra@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '0'],
#  ['35',
#   'MAJOR PROJECT PART 2 (BB5)                         ',
#   'BBD854',
#   'Q',
#   16.0,
#   0.0,
#   0.0,
#   32.0,
#   '',
#   'ASHISH MISRA   ',
#   'ashishmisra@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '11'],
#  ['36',
#   'MAJOR PROJECT                                      ',
#   'BBD895',
#   'Q',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   '',
#   'RITU KULSHRESHTHA   ',
#   'ritu@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '11'],
#  ['37',
#   'ENVIRONMENTAL BIOTECHNOLOGY                        ',
#   'BBL341',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DE',
#   'SHILPI SHARMA   ',
#   'shilpi@dbeb.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '100',
#   '13'],
#  ['38',
#   'BIOPROCESS TECHNOLOGY                              ',
#   'BBL431',
#   'J',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'DC',
#   'SHAIKH ZIAUDDIN AHAMMAD   ',
#   'zia@dbeb.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '100',
#   '77'],
#  ['39',
#   'FLUID SOLID SYSTEMS                                ',
#   'BBL432',
#   'H',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'DC',
#   'SUNIL NATH   ',
#   'sunath@dbeb.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '100',
#   '56'],
#  ['40',
#   'ENZYME SCIENCE AND ENGINEERING                     ',
#   'BBL433',
#   'D',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   'DC',
#   'RAVI KRISHNAN ELANGOVAN   ',
#   'elangovan@dbeb.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '100',
#   '55'],
#  ['41',
#   'BIOINFORMATICS                                     ',
#   'BBL434',
#   'C',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   'DC',
#   'D.SUNDAR   ',
#   'sundar@dbeb.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '100',
#   '73'],
#  ['42',
#   'MODELING & SIMULATION OF BIO.                      ',
#   'BBL443',
#   'J',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   'DE',
#   'ASHISH MISRA   ',
#   'ashishmisra@dbeb.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '100',
#   '13'],
#  ['43',
#   'MEMBRANE APPLICATIONS IN BIO.                      ',
#   'BBL445',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DE',
#   'G.P. AGARWAL   ',
#   'gopal@dbeb.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '100',
#   '33'],
#  ['44',
#   'DYNAMICS OF MICROBIAL SYSTEMS                      ',
#   'BBL736',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ATUL NARANG   ',
#   'anarang@dbeb.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '27'],
#  ['45',
#   'PLANT CELL TECHNOLOGY                              ',
#   'BBL740',
#   'K',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   '',
#   'ASHOK KUMAR SRIVASTAVA   ',
#   'ashokks@dbeb.iitd.ac.in',
#   'W 12:00-13:00 ,TF 17:00-18:00',
#   '',
#   '',
#   '60',
#   '19'],
#  ['46',
#   'BIOLOGICAL WASTE TREATMENT                         ',
#   'BBL742',
#   'D',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'T.R.SREEKRISHNAN   ',
#   'sree@dbeb.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '32'],
#  ['47',
#   'COMBINATORIAL BIOTECHNOLOGY                        ',
#   'BBL745',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PREETI SRIVASTAVA   ',
#   'preeti@dbeb.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '25'],
#  ['48',
#   'CURRENT TOPICS IN BIOCHEMICALENGINEERING AND BIOTE ',
#   'BBL746',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SAROJ MISHRA   ',
#   'sarojm@dbeb.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '15'],
#  ['49',
#   'BIONANOTECHNOLOGY                                  ',
#   'BBL747',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PRASHANT MISHRA   ',
#   'pmishra@dbeb.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '22'],
#  ['50',
#   'CANCER CELL BIOLOGY                                ',
#   'BBL749',
#   'F',
#   4.5,
#   3.0,
#   0.0,
#   3.0,
#   '',
#   'RITU KULSHRESHTHA   ',
#   'ritu@dbeb.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '36'],
#  ['51',
#   'SEMINAR COURSE   I                                 ',
#   'BBQ301',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'RAVI KRISHNAN ELANGOVAN   ',
#   'elangovan@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '20'],
#  ['52',
#   'SEMINAR COURSE   II                                ',
#   'BBQ302',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'SHILPI SHARMA   ',
#   'shilpi@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '16'],
#  ['53',
#   'SEMINAR COURSE   III                               ',
#   'BBQ303',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'SAROJ MISHRA   ',
#   'sarojm@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '20'],
#  ['54',
#   'MAJOR PROJECT                                      ',
#   'BED800',
#   'P',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   '',
#   'RITU KULSHRESHTHA   ',
#   'ritu@dbeb.iitd.ac.in',
#   '',
#   '',
#   '',
#   '10',
#   '1'],
#  ['55',
#   'MINOR PROJECT                                      ',
#   'CRD802',
#   'A',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   'PC',
#   'ANKUR GUPTA   ',
#   'ankurgupta@care.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '25'],
#  ['56',
#   'MAJOR PROJECT PART I                               ',
#   'CRD811',
#   'Q',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   'PC',
#   'ANKUR GUPTA   ',
#   'ankurgupta@care.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['57',
#   'MAJOR PROJECT PART 2                               ',
#   'CRD812',
#   'Q',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'ANKUR GUPTA   ',
#   'ankurgupta@care.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '22'],
#  ['58',
#   'MAJOR PROJECT III                                  ',
#   'CRD814',
#   'Q',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   'PC',
#   'ANKUR GUPTA   ',
#   'ankurgupta@care.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['59',
#   'ARCHITECTURES AND ALGORITHMS FOR DSP SYSTEMS       ',
#   'CRL702',
#   'E',
#   4.0,
#   2.0,
#   0.0,
#   4.0,
#   'PC',
#   'ARUN KUMAR   ',
#   'arunkm@care.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '40',
#   '27'],
#  ['60',
#   'SENSOR ARRAY SIGNAL PROCESSING                     ',
#   'CRL704',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PRABHU BABU   ',
#   'prabhubabu@care.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '15'],
#  ['61',
#   'SONARS                                             ',
#   'CRL706',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'RAJENDAR BAHL   ',
#   'rbahl@care.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '7'],
#  ['62',
#   'RF AND MICROWAVE ACTIVE CIRCUITS                   ',
#   'CRL712',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'SHIBAN KISHEN KOUL   ',
#   'skkoul1@care.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '60',
#   '26'],
#  ['63',
#   'RF AND MICROWAVE SOLID STATE DEVICES               ',
#   'CRL722',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'SAMARESH DAS   ',
#   'samareshdas@care.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '10'],
#  ['64',
#   'RF AND MICROWAVE MEASUREMENT SYSTEM TECHNIQUES     ',
#   'CRL724',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'ANANJAN BASU   ',
#   'ananjan@care.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '27'],
#  ['65',
#   'SELECTED TOPICS IN RFDT II                         ',
#   'CRL732',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'PUSHPAPRAJ SINGH   ',
#   'prsingh@care.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '8'],
#  ['66',
#   'SPECIAL MODULE IN RADIO FREQUENCY DESIGN & TECH. I ',
#   'CRV742',
#   'X',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'ARUN KUMAR   ',
#   'arunkm@care.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '20'],
#  ['67',
#   'PROJECT II                                         ',
#   'ASD882',
#   'Q',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'SANDEEP SAHANY   ',
#   'ssahany@cas.iitd.ac.in',
#   '',
#   '',
#   '',
#   '12',
#   '12'],
#  ['68',
#   'Fundamentals of Weather and Climate ',
#   'ASL340',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'SAGNIK DEY   ',
#   'sagnik@cas.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '80',
#   '68'],
#  ['69',
#   'INTRODUCTION TOOCEANOGRAPHY                        ',
#   'ASL350',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'VIMLESH PANT   ',
#   'vimlesh@cas.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '80',
#   '71'],
#  ['70',
#   'THE EARTH`S ATMOSPHERE:PHYSICAL PRINCIPLES         ',
#   'ASL360',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SAROJ KANTA MISHRA   ',
#   'skm@cas.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '80',
#   '80'],
#  ['71',
#   'DYNAMICS OF THE ATMOSPHERE                         ',
#   'ASL734',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MAITHILI SHARAN   ',
#   'mathilis@cas.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '30',
#   '24'],
#  ['72',
#   'SCIENCE OF CLIMATE CHANGE                          ',
#   'ASL736',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'KRISHNA MIRLE ACHUTARAO   ',
#   'akrishna@cas.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '25',
#   '21'],
#  ['73',
#   'PHYSICAL AND DYNAMICAL OCEANOGRAPHY                ',
#   'ASL737',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'A.D. RAO   ',
#   'adrao@cas.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '25',
#   '14'],
#  ['74',
#   'NUMERICAL MODELING OF THE ATMOSPHERE AND OCEAN     ',
#   'ASL738',
#   'AD',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   '',
#   'SANDEEP SAHANY   ',
#   'ssahany@cas.iitd.ac.in',
#   'TF 15:30-17:00',
#   '',
#   '',
#   '16',
#   '14'],
#  ['75',
#   'DISPERSION OF AIR POLLUTANTS                       ',
#   'ASL751',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'RAVI KUMAR KUNCHALA   ',
#   'rkkunchala@cas.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '40',
#   '21'],
#  ['76',
#   'CLOUD PHYSICS                                      ',
#   'ASL754',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'DILIP GANGULY   ',
#   'dilipganguly@cas.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '50',
#   '7'],
#  ['77',
#   'RENEWABLE ENERGY METEOROLOGY                       ',
#   'ASL760',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SOMNATH BAIDYA ROY   ',
#   'drsbr@cas.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '25',
#   '5'],
#  ['78',
#   'ADVANCED DATA ANALYSIS FOR WEATHER AND CLIMATE     ',
#   'ASP820',
#   'K',
#   3.0,
#   1.0,
#   0.0,
#   4.0,
#   '',
#   'SANDEEP  SUKUMARAN ',
#   'san81@cas.iitd.ac.in',
#   'W 12:00-13:00 ,TF 17:00-18:00',
#   '',
#   '',
#   '15',
#   '12'],
#  ['79',
#   'Major Project 2 ',
#   'BMD802',
#   'X',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'JAYANTA BHATTACHARYYA   ',
#   'jayanta@cbme.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '7'],
#  ['80',
#   'BIOMEDICAL SIGNAL AND IMAGE PR                     ',
#   'BML735',
#   'AD',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   'PE',
#   'ANUP SINGH   ',
#   'anupsm@cbme.iitd.ac.in',
#   'TF 15:30-17:00',
#   '',
#   '',
#   '60',
#   '35'],
#  ['81',
#   'APPLICATIONS OF MATHEMATICS IN BIOMEDICAL ENG.     ',
#   'BML737',
#   'D',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'PC',
#   'ANUP SINGH   ',
#   'anupsm@cbme.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '16'],
#  ['82',
#   'BIOMEDICAL INSTRUMENTATION                         ',
#   'BML740',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'DEEPAK JOSHI   ',
#   'joshid@cbme.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '17'],
#  ['83',
#   'POINT OF CARE MEDICAL DIAG DEV                     ',
#   'BML750',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'SANDEEP KUMAR JHA   ',
#   'sandeepjha@cbme.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '5'],
#  ['84',
#   'BIOMEDICAL ETHICS, SAFETY AND REGULATORY AFFAIRS   ',
#   'BML760',
#   'B',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'PC',
#   'SANDEEP KUMAR JHA   ',
#   'sandeepjha@cbme.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '9'],
#  ['85',
#   'Orthopaedic Device Design ',
#   'BML771',
#   'H',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'PE',
#   'DINESH KALYANASUNDARAM   ',
#   'dineshk@cbme.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '8'],
#  ['86',
#   'BIOMATERIALS                                       ',
#   'BML820',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'HARPAL SINGH   ',
#   'harpal@cbme.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '8'],
#  ['87',
#   'NANOMEDICINE                                       ',
#   'BML860',
#   'K',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'NEETU SINGH   ',
#   'sneetu@cbme.iitd.ac.in',
#   'W 12:00-13:00 ,TF 17:00-18:00',
#   '',
#   '',
#   '60',
#   '9'],
#  ['88',
#   'BASIC BIOMEDICAL LABORATORY                        ',
#   'BMP743',
#   'X',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   'PC',
#   'JAYANTA BHATTACHARYYA   ',
#   'jayanta@cbme.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '7'],
#  ['89',
#   'SELF ORGANIZING DYNAMICAL SYSTEMS                  ',
#   'ESL300',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MRS. R. UMA   ',
#   'ruma@ces.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '61'],
#  ['90',
#   'ENERGY, ECOLOGY AND ENVIRONMENT                    ',
#   'ESL330',
#   'D',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   '',
#   'SUPRAVAT KARAK   ',
#   'supravat@ces.iitd.ac.in',
#   'TWF 09:00-10:00',
#   'MTThF 14:00-15:00',
#   '',
#   '60',
#   '61'],
#  ['91',
#   'NON CONVENTIONAL SOURCES OF ENERGY                 ',
#   'ESL340',
#   'E',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'K RAVI KUMAR   ',
#   'krk@ces.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '15'],
#  ['92',
#   'ENERGY CONSERVATION MANAGEMENT                     ',
#   'ESL350',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'S K TYAGI ',
#   'tyagisk@ces.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '75',
#   '62'],
#  ['93',
#   'DIRECT ENERGY CONVERSION                           ',
#   'ESL360',
#   'F',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   '',
#   'DEBAPRASAD SAHU   ',
#   'dpsahu@ces.iitd.ac.in',
#   'TWF 11:00-12:00',
#   'MTThF 13:00-14:00',
#   '',
#   '60',
#   '16'],
#  ['94',
#   'ENERGY,ECOLOGY AND ENVIRONMENT                     ',
#   'ESL710',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'K.A. SUBRAMANIAN   ',
#   'subra@ces.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '35'],
#  ['95',
#   'POWER PLANT ENGG.                                  ',
#   'ESL714',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'DIBAKAR RAKSHIT   ',
#   'dibakar@ces.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '16'],
#  ['96',
#   'POWER GENERATION ,TRANSMISSION & DISTRIBUTION      ',
#   'ESL718',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'T.S.BHATTI   ',
#   'tsb@ces.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '60',
#   '12'],
#  ['97',
#   'DIRECT ENERGY CONVERSION                           ',
#   'ESL730',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'RAMESH NARAYANAN   ',
#   'rams@ces.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '24'],
#  ['98',
#   'NUCLEAR ENERGY                                     ',
#   'ESL734',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'DEBAPRASAD SAHU   ',
#   'dpsahu@ces.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '12'],
#  ['99',
#   'ECONOMICS & PLANNING OF ENERGY SYSTEMS             ',
#   'ESL750',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'T.C. KANDPAL   ',
#   'tarak@ces.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '60',
#   '29'],
#  ['100',
#   'SOLAR PHOTOVOLTAIC DEVICES AND SYSTEMS             ',
#   'ESL755',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SANDEEP KUMAR PATHAK   ',
#   'spathak@ces.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '14'],
#  ['101',
#   'OPERATION AND CONTROL OF ELECTRICAL ENERGY SYSTEMS ',
#   'ESL796',
#   'AA',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SUMIT KUMAR CHATTOPA   ',
#   'sumit@ces.iitd.ac.in',
#   'MTh 14:00-15:30',
#   '',
#   '',
#   '60',
#   '8'],
#  ['102',
#   'SOLAR ARCHITECTURE                                 ',
#   'ESL840',
#   'AA',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'S K TYAGI ',
#   'tyagisk@ces.iitd.ac.in',
#   'MTh 14:00-15:30',
#   '',
#   '',
#   '60',
#   '7'],
#  ['103',
#   'ADVANCAED FUSION ENERGY                            ',
#   'ESL871',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MRS. R. UMA   ',
#   'ruma@ces.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '11'],
#  ['104',
#   'SOLAR THERMAL POWER GENERATION                     ',
#   'ESL880',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'K RAVI KUMAR   ',
#   'krk@ces.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '60',
#   '11'],
#  ['105',
#   'ENERGY LABORATORY                                  ',
#   'ESP713',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   'PC',
#   'KAUSHIK  SAHA  ',
#   'kaushiksaha@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '35',
#   '23'],
#  ['106',
#   'SEMINAR COURSE   I                                 ',
#   'ESQ301',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'SANDEEP KUMAR PATHAK   ',
#   'spathak@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '26'],
#  ['107',
#   'SEMINAR COURSE III                                 ',
#   'ESQ303',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'SUMIT KUMAR CHATTOPA   ',
#   'sumit@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '24'],
#  ['108',
#   'SEMINAR COURSE IV                                  ',
#   'ESQ304',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'RAMESH NARAYANAN   ',
#   'rams@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '24'],
#  ['109',
#   'SEMINAR COURSE ON BIOENERGY                        ',
#   'ESQ306',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'S K TYAGI ',
#   'tyagisk@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '17'],
#  ['110',
#   'SEMINAR COURSE ON NUCLEARENERGY AND FUTURISTIC USE ',
#   'ESQ307',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'MRS. R. UMA   ',
#   'ruma@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '25'],
#  ['111',
#   'SEMINAR COURSE ONENERGY ENVIRONMENT INTERACTION    ',
#   'ESQ308',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'K RAVI KUMAR   ',
#   'krk@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '22'],
#  ['112',
#   'SEMINAR COURSE ON ALTERNATIVEFUELS FOR TRANSPORTAT ',
#   'ESQ309',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'K.A. SUBRAMANIAN   ',
#   'subra@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '23'],
#  ['113',
#   'NGU: Seminar Course on Multiphase Flows in the Energy Sector ',
#   'ESQ310',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'KAUSHIK  SAHA  ',
#   'kaushiksaha@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '4'],
#  ['114',
#   'MAJOR PROJECT PART I                               ',
#   'JSD801',
#   'P',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   'PC',
#   'RAMESH NARAYANAN   ',
#   'rams@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '35',
#   '0'],
#  ['115',
#   'MAJOR PROJECT PART II                              ',
#   'JSD802',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PE',
#   'RAMESH NARAYANAN   ',
#   'rams@ces.iitd.ac.in',
#   '',
#   '',
#   '',
#   '35',
#   '6'],
#  ['116',
#   'MINOR PROJECT                                      ',
#   'RDD750',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   'OE',
#   'HARIPRASAD P.   ',
#   'phari@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '1'],
#  ['117',
#   'BIOMAS PRODUCTION                                  ',
#   'RDL700',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'HARIPRASAD P.   ',
#   'phari@rdat.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '49'],
#  ['118',
#   'RURAL INDUSTRIALISATION POLICES PROGRAMMES & CASE  ',
#   'RDL701',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'KAVYA DASHORA   ',
#   'kdashora@rdat.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '100',
#   '99'],
#  ['119',
#   'RURAL INDIA AND PLANNING FOR DEVELOPMENT           ',
#   'RDL710',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'VIVEK   KUMAR ',
#   'vivekk@rdat.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '50',
#   '65'],
#  ['120',
#   'RURAL ENERGY SYSTEMS                               ',
#   'RDL722',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'VIRENDRA KUMAR VIJAY   ',
#   'vkvijay@rdat.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '100',
#   '102'],
#  ['121',
#   'HERBAL,MEDICINAL ANDAROMATIC PRODUCTS              ',
#   'RDL726',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'S.N.NAIK   ',
#   'snn@rdat.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '30',
#   '30'],
#  ['122',
#   'TECHNOLOGY OF UTILIZATION OF WASTELANDS & WEEDS    ',
#   'RDL740',
#   'AA',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'ANUSHREE MALIK   ',
#   'anushree@rdat.iitd.ernet.in',
#   'MTh 14:00-15:30',
#   '',
#   '',
#   '50',
#   '44'],
#  ['123',
#   'FOOD QUALITY AND SAFETY                            ',
#   'RDL760',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'OE',
#   'SANTOSH   ',
#   'ssatya@rdat.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '50',
#   '55'],
#  ['124',
#   'BIOMASS LABORATORY                                 ',
#   'RDP750',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   'OE',
#   'HARIPRASAD P.   ',
#   'phari@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '20',
#   '13'],
#  ['125',
#   'SEMINAR COURSE   I                                 ',
#   'RDQ301',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'OE',
#   'JATINDRA KUMAR SAHU   ',
#   'jksahu@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '32'],
#  ['126',
#   'SEMINAR COURSE   II                                ',
#   'RDQ302',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'OE',
#   'S.N.NAIK   ',
#   'snn@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '33'],
#  ['127',
#   'SEMINAR COURSE   III                               ',
#   'RDQ303',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'OE',
#   'VIVEK   KUMAR ',
#   'vivekk@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '34'],
#  ['128',
#   'SEMINAR COURSE IV                                  ',
#   'RDQ304',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'OE',
#   'RAM  CHANDRA ',
#   'rchandra@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '31'],
#  ['129',
#   'SEMINAR COURSE V                                   ',
#   'RDQ305',
#   'X',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'OE',
#   'KAVYA DASHORA   ',
#   'kdashora@rdat.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '44'],
#  ['130',
#   'MINOR PROJECT                                      ',
#   'CHD771',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '0'],
#  ['131',
#   'MAJOR PROJECT PART 1 (CM)                          ',
#   'CHD871',
#   'Q',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '2'],
#  ['132',
#   'MAJOR PROJECT PART II (CM)                         ',
#   'CHD872',
#   'Q',
#   14.0,
#   0.0,
#   0.0,
#   28.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['133',
#   'MAJOR PROJECT PART 1 (CM)                          ',
#   'CHD873',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '0'],
#  ['134',
#   'MAJOR PROJECT PART 2 (CM)                          ',
#   'CHD874',
#   'Q',
#   16.0,
#   0.0,
#   0.0,
#   32.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '0'],
#  ['135',
#   'B. TECH. PROJECT                                   ',
#   'CLD411',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   'DC',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '13'],
#  ['136',
#   'MAJOR PROJECT IN ENERGY & ENV.                     ',
#   'CLD412',
#   'Q',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   'DE',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '5'],
#  ['137',
#   'MAJOR PROJECT IN COMPLEX FLUID                     ',
#   'CLD413',
#   'Q',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   'DE',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '0'],
#  ['138',
#   'MAJOR PROJ. IN P.E, MOD. & OP.                     ',
#   'CLD414',
#   'Q',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   'DE',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '0'],
#  ['139',
#   'MAJOR PROJ IN BIOP. & FINE CH.                     ',
#   'CLD415',
#   'Q',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   'DE',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '3'],
#  ['140',
#   'MINOR PROJECT                                      ',
#   'CLD771',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '32'],
#  ['141',
#   'MAJOR PROJECT   I                                  ',
#   'CLD781',
#   'Q',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['142',
#   'MAJOR PROJECT   II                                 ',
#   'CLD782',
#   'Q',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '15'],
#  ['143',
#   'MINOR PROJECT                                      ',
#   'CLD880',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '42'],
#  ['144',
#   'MAJOR PROJECT PARTI                                ',
#   'CLD881',
#   'Q',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '2'],
#  ['145',
#   'MAJOR PROJECT PARTII                               ',
#   'CLD882',
#   'Q',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '39'],
#  ['146',
#   'CHEMICAL ENGG. THERMODYNAMICS                      ',
#   'CLL121',
#   'A',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'GAURAV GOEL   ',
#   'goelg@chemical.iitd.ac.in',
#   'MTh 08:00-09:30',
#   'MTThF 13:00-14:00',
#   '',
#   '100',
#   '143'],
#  ['147',
#   'CHEMICAL REACTION ENGG I                           ',
#   'CLL122',
#   'D',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'DIVESH BHATIA   ',
#   'dbhatia@chemical.iitd.ac.in',
#   'TWF 09:00-10:00',
#   'MTThF 14:00-15:00',
#   '',
#   '100',
#   '178'],
#  ['148',
#   'FLUID MECHS. FOR CHEM. ENGINEE                     ',
#   'CLL231',
#   'F',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'JYOTI PHIRANI   ',
#   'jphirani@chemical.iitd.ac.in',
#   'TWF 11:00-12:00',
#   'MTThF 13:00-14:00',
#   '',
#   '100',
#   '194'],
#  ['149',
#   'HEAT TRANSFER FOR CHEMICAL ENG                     ',
#   'CLL251',
#   'B',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'MANOJKUMAR CHARANDAS RAMTEKE   ',
#   'mcramteke@chemical.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '100',
#   '187'],
#  ['150',
#   'INTRO TO INDUSTRIAL BIOTECH.                       ',
#   'CLL271',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'ANURAG SINGH RATHORE   ',
#   'arathore@chemical.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '100',
#   '108'],
#  ['151',
#   'MASS TRANSFER II                                   ',
#   'CLL352',
#   'B',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'ANIL VERMA   ',
#   'anilverma@chemical.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '100',
#   '118'],
#  ['152',
#   'INSTRUMENTATION AND AUTOMATION                     ',
#   'CLL361',
#   'C',
#   2.5,
#   1.0,
#   0.0,
#   3.0,
#   'DC',
#   'SHAIK ABDUL MUNAWAR   ',
#   'munawar@chemical.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '100',
#   '106'],
#  ['153',
#   'CHEM. PROCESS TECH.& ECONOMICS                     ',
#   'CLL371',
#   'E',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'SHANTANU ROY   ',
#   'roys@chemical.iitd.ac.in',
#   'TWF 10:00-11:00',
#   'MTThF 13:00-14:00',
#   '',
#   '100',
#   '127'],
#  ['154',
#   'PROCESS PLANT DESIGN                               ',
#   'CLL402',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DE',
#   'SREEDEVI UPADHYAYULA   ',
#   'sreedevi@chemical.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '50',
#   '12'],
#  ['155',
#   'SAFETY & HAZARDS IN PROC. IND.                     ',
#   'CLL475',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DE',
#   'ANIL KUMAR SAROHA   ',
#   'aksaroha@chemical.iitd.ernet.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '50',
#   '25'],
#  ['156',
#   'ELECTROCHEM. CONV. & STO. DEV.                     ',
#   'CLL722',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ANUPAM SHUKLA   ',
#   'anupam@chemical.iitd.ernet.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '50',
#   '36'],
#  ['157',
#   'HETERO. CATALYSIS & CATA. REA.                     ',
#   'CLL727',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'KAMAL KISHORE PANT   ',
#   'kkpant@chemical.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '50',
#   '41'],
#  ['158',
#   'ADVANCED TRANSPORT PHENOMENA                       ',
#   'CLL731',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'VIVEK VITTHAL BUWA   ',
#   'vvbuwa@chemical.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '60',
#   '100'],
#  ['159',
#   'ADV. CHE. ENGG. THERMODYNAMICS                     ',
#   'CLL732',
#   'AA',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'MOHAMMAD ALI HAIDER   ',
#   'haider@chemical.iitd.ac.in',
#   'MTh 14:00-15:30',
#   '',
#   '',
#   '60',
#   '20'],
#  ['160',
#   'INDUSTRIAL MULTIPHASE REACTORS                     ',
#   'CLL733',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC,DE,PE',
#   'RATAN MOHAN   ',
#   'ratan@chemical.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '110',
#   '115'],
#  ['161',
#   'INTERFACIAL ENGINEERING                            ',
#   'CLL766',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'A.N. BHASKARWAR   ',
#   'ashoknb@chemical.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '50',
#   '61'],
#  ['162',
#   'STRUCTURES & PROP. OF POLYMERS                     ',
#   'CLL767',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SUDIP KUMAR PATTANAYEK   ',
#   'sudip@chemical.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '50',
#   '22'],
#  ['163',
#   'FUNDAMENTALS OF COMP. FLUID DY                     ',
#   'CLL768',
#   'F',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   '',
#   'JAYATI SARKAR   ',
#   'jayati@chemical.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '30',
#   '12'],
#  ['164',
#   'INTRODUCTION TO COMPLEX FLUIDS                     ',
#   'CLL771',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'VIKRAM SINGH   ',
#   'vs225@chemical.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '50',
#   '32'],
#  ['165',
#   'TRANS. PHEN. IN COMPLEX FLUIDS                     ',
#   'CLL772',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PARESH PRAVINCHANDRA CHOKSHI   ',
#   'paresh@chemical.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '50',
#   '12'],
#  ['166',
#   'MOL. BIOTECH. & IN VITRO DIAG.                     ',
#   'CLL779',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SHALINI GUPTA   ',
#   'shalinig@chemical.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '50',
#   '12'],
#  ['167',
#   'PROCESS OPTIMIZATION                               ',
#   'CLL782',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SHAIK ABDUL MUNAWAR   ',
#   'munawar@chemical.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '50',
#   '34'],
#  ['168',
#   'FINE CHEMICALS TECHNOLOGY                          ',
#   'CLL786',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'RAJESH KHANNA   ',
#   'rajkh@chemical.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '50',
#   '56'],
#  ['169',
#   'Process Data Analytics ',
#   'CLL788',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'HARIPRASAD  KODAMANA ',
#   'kodamana@chemical.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '56'],
#  ['170',
#   'MEMBRANE SCIENCE & ENGINEERING                     ',
#   'CLL793',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'S.K. GUPTA   ',
#   'sgupta@chemical.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '50',
#   '50'],
#  ['171',
#   'CHEMICAL ENGINEERING LAB   II                      ',
#   'CLP302',
#   'E',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   'DC',
#   'VIKRAM SINGH   ',
#   'vs225@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '159'],
#  ['172',
#   'TECHNICAL COMMUNICATION FOR CHEMICAL ENGINEERS     ',
#   'CLP704',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'MOHAMMAD ALI HAIDER   ',
#   'haider@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '66'],
#  ['173',
#   'SEMINAR COURSE   I                                 ',
#   'CLQ301',
#   'P',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'A.N. BHASKARWAR   ',
#   'ashoknb@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '35',
#   '43'],
#  ['174',
#   'SEMINAR COURSE   II                                ',
#   'CLQ302',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'RATAN MOHAN   ',
#   'ratan@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '35',
#   '33'],
#  ['175',
#   'RECENT  ADV. IN CHEMICAL ENGG.                     ',
#   'CLV797',
#   'X',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   '',
#   'KSHITIJ CHANDRA JHA   ',
#   'kcjha@chemical.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '8'],
#  ['176',
#   'PROJECT PART II                                    ',
#   'CMD641',
#   'P',
#   10.0,
#   0.0,
#   0.0,
#   20.0,
#   '',
#   'SAMEER SAPRA   ',
#   'sapra@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '49'],
#  ['177',
#   'MAJOR  PROJECT PART   II                           ',
#   'CMD807',
#   'P',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   '',
#   'NIDHI JAIN   ',
#   'njain@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '11'],
#  ['178',
#   'INTRODUCTION TO CHEMISTRY                          ',
#   'CML100',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'GHOLAP SHIVAJIRAO LAHU   ',
#   'slgholap@chemistry.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '200',
#   '461'],
#  ['179',
#   'MOLECULAR THERMODYNAMICS                           ',
#   'CML521',
#   'C',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'B. JAYARAM   ',
#   'bjayaram@chemistry.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '60',
#   '55'],
#  ['180',
#   'CHEMICAL DYNA. & SURFACE CHEM.                     ',
#   'CML522',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'PRAVIN POPINAND INGOLE   ',
#   'ppingole@chemistry.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '54'],
#  ['181',
#   'ORGANIC SYNTHESIS                                  ',
#   'CML523',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'N.G.RAMESH   ',
#   'ramesh@chemistry.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '55'],
#  ['182',
#   'TRAN. & INNER TRAN. METAL CHE.                     ',
#   'CML524',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'D.K. BANDYOPADHYAY   ',
#   'dkbp@chemistry.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '60',
#   '54'],
#  ['183',
#   'BASIC ORGANOMETALIC CHEMISTRY                      ',
#   'CML525',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'S.NAGENDRAN   ',
#   'sisn@chemistry.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '54'],
#  ['184',
#   'STR. & FUNC. OF CELLULAR BIOM.                     ',
#   'CML526',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'TANMAY DUTTA   ',
#   'dtanmay@chemistry.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '54'],
#  ['185',
#   'BIOPHYSICAL CHEMISTRY                              ',
#   'CML665',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SHASHANK DEEP   ',
#   'sdeep@chemistry.iitd.ernet.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '8'],
#  ['186',
#   'Bio organic and Medicinal chemistry                ',
#   'CML673',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'NALIN PANT   ',
#   'nalinp@chemistry.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '7'],
#  ['187',
#   'Inorganic Polymers ',
#   'CML682',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'RAVI SHANKAR   ',
#   'shankar@chemistry.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '30'],
#  ['188',
#   'SYNTHESIS OF INDUSTRIALLY IMPO                     ',
#   'CML724',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'KUNTAL MANNA   ',
#   'kmanna@chemistry.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '60',
#   '30'],
#  ['189',
#   'MATERIAL CHARACTERIZATION                          ',
#   'CML729',
#   'C',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'JAI DEO SINGH   ',
#   'jaideo@chemistry.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '60',
#   '28'],
#  ['190',
#   'APPLIED SPECTROSCOPY                               ',
#   'CML737',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'NIDHI JAIN   ',
#   'njain@chemistry.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '31'],
#  ['191',
#   'APPLICATIONS OF P BLOCK ELEMEN                     ',
#   'CML738',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ANIL JACOB ELIAS   ',
#   'elias@chemistry.iitd.ernet.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '16'],
#  ['192',
#   'APPLIED BIOCATALYSIS                               ',
#   'CML739',
#   'K',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'SUNIL KUMAR KHARE   ',
#   'skkhare@chemistry.iitd.ac.in',
#   'W 12:00-13:00 ,TF 17:00-18:00',
#   '',
#   '',
#   '60',
#   '28'],
#  ['193',
#   'CHEMISTRY OF HETEROCYCLIC COMP                     ',
#   'CML740',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'RAVI P. SINGH   ',
#   'ravips@chemistry.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '60',
#   '33'],
#  ['194',
#   'MOLECULAR MODELLING AND SIMULA                     ',
#   'CML801',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'HEMANT KUMAR KASHYAP   ',
#   'hkashyap@chemistry.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '21'],
#  ['195',
#   'CHEMISTRY LABORATORY                               ',
#   'CMP100',
#   'P',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'PRAMIT KUMAR CHOWDHURY   ',
#   'pramitc@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '1000',
#   '458'],
#  ['196',
#   'LAB III                                            ',
#   'CMP521',
#   'P',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'N.G.RAMESH   ',
#   'ramesh@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '240',
#   '53'],
#  ['197',
#   'LAB IV                                             ',
#   'CMP522',
#   'P',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'TANMAY DUTTA   ',
#   'dtanmay@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '240',
#   '53'],
#  ['198',
#   'INSTRUMENTATION LABORATORY                         ',
#   'CMP728',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'JAI DEO SINGH   ',
#   'jaideo@chemistry.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '8'],
#  ['199',
#   'SEMINAR IN CONSTRUCTION TECHNO                     ',
#   'CVC772',
#   'R',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'KUMAR NEERAJ JHA   ',
#   'knjha@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '30'],
#  ['200',
#   'BTECH PROJECT PART 1                               ',
#   'CVD411',
#   'P',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   '',
#   'ARAVIND KRISHNA SWAMY   ',
#   'akswamy@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '30'],
#  ['201',
#   'BTECH PROJECT PART 2                               ',
#   'CVD412',
#   'P',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'ARAVIND KRISHNA SWAMY   ',
#   'akswamy@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '15'],
#  ['202',
#   'MINOR PROJECT                                      ',
#   'CVD700',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'R. AYOTHIRAMAN   ',
#   'araman@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '5',
#   '0'],
#  ['203',
#   'MINOR PROJECT                                      ',
#   'CVD710',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'TANUSREE CHAKRABORTY   ',
#   'tanusree@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '5',
#   '0'],
#  ['204',
#   'MAJOR THESIS PART I                                ',
#   'CVD720',
#   'M',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'GAZALA HABIB   ',
#   'gazala@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '24',
#   '0'],
#  ['205',
#   'MAJOR THESIS PART II                               ',
#   'CVD721',
#   'M',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'GAZALA HABIB   ',
#   'gazala@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '6'],
#  ['206',
#   'MINOR PROJECT IN STRUCTURAL ENGINEERING            ',
#   'CVD756',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'SUPRATIC GUPTA   ',
#   'supratic@civil.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '50',
#   '0'],
#  ['207',
#   'MAJOR PROJECT PART I (CES)                         ',
#   'CVD757',
#   'P',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   '',
#   'SUPRATIC GUPTA   ',
#   'supratic@civil.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '50',
#   '0'],
#  ['208',
#   'MAJOR PROJECT PART II (CES)                        ',
#   'CVD758',
#   'P',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   '',
#   'SUPRATIC GUPTA   ',
#   'supratic@civil.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '50',
#   '17'],
#  ['209',
#   'MAJOR PROJECT PART I (CEC)                         ',
#   'CVD772',
#   'P',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   '',
#   'KUMAR NEERAJ JHA   ',
#   'knjha@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '50',
#   '0'],
#  ['210',
#   'MAJOR PROJECT PART II (CEC)                        ',
#   'CVD773',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'KUMAR NEERAJ JHA   ',
#   'knjha@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '24'],
#  ['211',
#   'MINOR PROJECT (CET)                                ',
#   'CVD776',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'J. UMA MAHESWARI   ',
#   'umapaul@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '50',
#   '0'],
#  ['212',
#   'MAJOR PROJECT PART I (CET)                         ',
#   'CVD777',
#   'P',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   '',
#   'KUMAR NEERAJ JHA   ',
#   'knjha@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '50',
#   '1'],
#  ['213',
#   'MAJOR PROJECT PART II (CET)                        ',
#   'CVD778',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'J. UMA MAHESWARI   ',
#   'umapaul@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '19'],
#  ['214',
#   'MAJOR THESIS PART II                               ',
#   'CVD801',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'R. AYOTHIRAMAN   ',
#   'araman@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '8'],
#  ['215',
#   'MAJOR PROJECT PART I                               ',
#   'CVD810',
#   'P',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   '',
#   'TANUSREE CHAKRABORTY   ',
#   'tanusree@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '2'],
#  ['216',
#   'MAJOR PROJECT PART II (CEU)                        ',
#   'CVD811',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'TANUSREE CHAKRABORTY   ',
#   'tanusree@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '26',
#   '16'],
#  ['217',
#   'MAJOR PROJECT PART II                              ',
#   'CVD832',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'SUMEDHA CHAKMA   ',
#   'chakma@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '50',
#   '12'],
#  ['218',
#   'MAJOR PROJECT PART II                              ',
#   'CVD854',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   '',
#   'NEZAMUDDIN   ',
#   'nezam@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '12'],
#  ['219',
#   'MSR MAJOR PROJECT                                  ',
#   'CVD895',
#   'P',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   '',
#   'DEO RAJ KAUSHAL   ',
#   'kaushal@civil.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '2'],
#  ['220',
#   'ENVIRONMENTAL SCIENCE                              ',
#   'CVL100',
#   'C',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   '',
#   'SRI HARSHA KOTA   ',
#   'harshakota@civil.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '500',
#   '550'],
#  ['221',
#   'ENVIRONMENTAL ENGINEERING                          ',
#   'CVL212',
#   'B',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'ARUN KUMAR   ',
#   'arunku@civil.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '120',
#   '97'],
#  ['222',
#   'SOIL MECHANICS                                     ',
#   'CVL222',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'VENKATA RAMANA GUNTURI   ',
#   'ramana@civil.iitd.ac.in',
# ...
#   '65',
#   '61'],
#  ['732',
#   'SELECTED TOPICS IN APPLIED OPT                     ',
#   'PYL879',
#   'X',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'JOBY JOSEPH   ',
#   'joby@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['733',
#   'FIBER OPTIC COMPONENTS AND DEVICES                 ',
#   'PYL891',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ARUN KUMAR   ',
#   'akumar@physics.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '60',
#   '16'],
#  ['734',
#   'PHYSICS LABORATORY                                 ',
#   'PYP100',
#   'Q',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'NEERAJ KHARE   ',
#   'nkhare@physics.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '100',
#   '459'],
#  ['735',
#   'ENGG. PHYSICS LABORATORY II                        ',
#   'PYP212',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'SUNIL KUMAR   ',
#   'kumarsunil@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '47'],
#  ['736',
#   'ENGINEERING PHYSICS LAB.   IV                      ',
#   'PYP222',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   '',
#   'R.K. SONI   ',
#   'ravisoni@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '56'],
#  ['737',
#   'LABORATORY II                                      ',
#   'PYP562',
#   'Q',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   '',
#   'P.SENTHILKUMARAN   ',
#   'psenthil@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '51'],
#  ['738',
#   'SOLID STATE MATERIALS LABORATORY II                ',
#   'PYP702',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'PINTU DAS   ',
#   'pintu@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '20'],
#  ['739',
#   'ADVANCED OPTICS LABORATORY                         ',
#   'PYP762',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'JOBY JOSEPH   ',
#   'joby@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '17'],
#  ['740',
#   'ADVANCED OPTICAL WORKSHOP                          ',
#   'PYP764',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'JOBY JOSEPH   ',
#   'joby@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '1'],
#  ['741',
#   'SEMINAR COURSE   III                               ',
#   'PYQ303',
#   'Q',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'JOBY JOSEPH   ',
#   'joby@physics.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '76'],
#  ['742',
#   'INDEPENDENT STUDY                                  ',
#   'PYS300',
#   'X',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   '',
#   'SANTANU GHOSH   ',
#   'santanu1@physics.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '100',
#   '2'],
#  ['743',
#   'GRADUATE STUDENT SEMINAR II                        ',
#   'SBC796',
#   'P',
#   0.5,
#   0.0,
#   0.0,
#   1.0,
#   '',
#   'CHINMOY SANKAR DEY   ',
#   'csdey@bioschool.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '13'],
#  ['744',
#   'MINI PROJECT                                       ',
#   'SBD301',
#   'Q',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'ARCHANA CHUGH   ',
#   'achugh@bioschool.iitd.ac.in',
#   '',
#   '',
#   '',
#   '10',
#   '3'],
#  ['745',
#   'MS RESEARCH PROJECT                                ',
#   'SBD895',
#   'P',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   '',
#   'ARCHANA CHUGH   ',
#   'achugh@bioschool.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '5'],
#  ['746',
#   'INTRO. TO BIOLOGY FOR ENGINEER                     ',
#   'SBL100',
#   'C',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'MANIDIPA BANERJEE   ',
#   'mbanerjee@bioschool.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '600',
#   '402'],
#  ['747',
#   'HIGH DIMENSIONAL BIOLOGY                           ',
#   'SBL201',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ASHOK KUMAR PATEL   ',
#   'ashokpatel@bioschool.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '14'],
#  ['748',
#   'BIOMETRY                                           ',
#   'SBL701',
#   'M',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ADITYA MITTAL   ',
#   'amittal@bioschool.iitd.ac.in',
#   'MTh 17:00-18:30',
#   '',
#   '',
#   '60',
#   '10'],
#  ['749',
#   'ADVANCED CELL BIOLOGY                              ',
#   'SBL703',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'BISHWAJIT KUNDU   ',
#   'bkundu@bioschool.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '50',
#   '14'],
#  ['750',
#   'HUMAN VIROLOGY                                     ',
#   'SBL704',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'VIVEKANANDAN PERUMAL   ',
#   'vperumal@bioschool.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '60',
#   '12'],
#  ['751',
#   'BIOLOGY OF PROTEINS                                ',
#   'SBL705',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'TAPAN KUMAR CHAUDHURI   ',
#   'tkchaudhuri@bioschool.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '19'],
#  ['752',
#   'PLANT BIOTECH. & HUMAN HEALTH                      ',
#   'SBL714',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ARCHANA CHUGH   ',
#   'achugh@bioschool.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '60',
#   '1'],
#  ['753',
#   'GENOME AND HEALTHCARE                              ',
#   'SBL720',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'ASHOK KUMAR PATEL   ',
#   'ashokpatel@bioschool.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '60',
#   '5'],
#  ['754',
#   'INTRODUCTION TO PRACTICAL MODERN BIOLOGY           ',
#   'SBP200',
#   'Q',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'ADITYA MITTAL   ',
#   'amittal@bioschool.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '7'],
#  ['755',
#   'INDEPENDENT STUDY                                  ',
#   'SBS800',
#   'Q',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   '',
#   'ARCHANA CHUGH   ',
#   'achugh@bioschool.iitd.ac.in',
#   '',
#   '',
#   '',
#   '10',
#   '1'],
#  ['756',
#   'BIOINSPIRATION AND BIOMIMETICS                     ',
#   'SBV750',
#   'K',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'ARCHANA CHUGH   ',
#   'achugh@bioschool.iitd.ac.in',
#   'W 12:00-13:00 ,TF 17:00-18:00',
#   '',
#   '',
#   '60',
#   '21'],
#  ['757',
#   'ELEMENTS OF NEUROSCIENCE                           ',
#   'SBV884',
#   'J',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'JAMES GOMES   ',
#   'jgomes@bioschool.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '60',
#   '8'],
#  ['758',
#   'MAJOR PROJECT(MSR)                                 ',
#   'BSD895',
#   'P',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   '',
#   'HARSHAN JAGADEESH   ',
#   'jharshan@ee.iitd.ac.in',
#   '',
#   '',
#   '',
#   '60',
#   '4'],
#  ['759',
#   'MINOR PROJECT IN INFORMATION TECHNOLOGY            ',
#   'SID880',
#   'P',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   '',
#   'PREETI RANJAN PANDA   ',
#   'panda@cse.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '30',
#   '0'],
#  ['760',
#   'MS RESEARCH PROJECT                                ',
#   'SID890',
#   'P',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   '',
#   'PREETI RANJAN PANDA   ',
#   'panda@cse.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '30',
#   '4'],
#  ['761',
#   'NETWORKS & SYSTEM SECURITY                         ',
#   'SIL765',
#   'B',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   '',
#   'B.N.JAIN   ',
#   'bnj@cse.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '40',
#   '33'],
#  ['762',
#   'SPECIAL MODULE ON INTELLIGENT INFO. PROCESSING     ',
#   'SIV895',
#   'P',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'PREM KUMAR KALRA   ',
#   'pkalra@cse.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '1'],
#  ['763',
#   'COLLOQUIUM (TT)                                    ',
#   'TTC410',
#   'P',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   '',
#   'ABHIJIT MAJUMDAR   ',
#   'majumdar@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '2'],
#  ['764',
#   'PRACTICAL TRAINING                                 ',
#   'TTT410',
#   'P',
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   '',
#   'S.M. ISHTIAQUE   ',
#   'ishtiaque@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '10',
#   '2'],
#  ['765',
#   'MINOR DESIGN PROJECT   VII                         ',
#   'TXD357',
#   'P',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'R. CHATTOPADHYAY   ',
#   'rchat@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '1'],
#  ['766',
#   'MINOR DESIGN PROJECT VIII                          ',
#   'TXD358',
#   'P',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   '',
#   'R. CHATTOPADHYAY   ',
#   'rchat@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '1'],
#  ['767',
#   'MAJOR PROJECT PART I                               ',
#   'TXD401',
#   'P',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   'DC',
#   'JAVED NABIBAKSHA SHEIKH   ',
#   'jnsheikh@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '14'],
#  ['768',
#   'MAJOR PROJECT PART II                              ',
#   'TXD402',
#   'P',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   '',
#   'JAVED NABIBAKSHA SHEIKH   ',
#   'jnsheikh@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '19'],
#  ['769',
#   'MAJOR PROJECT PART II                              ',
#   'TXD803',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'ABHIJIT MAJUMDAR   ',
#   'majumdar@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '22'],
#  ['770',
#   'MAJOR PROJECT PART II                              ',
#   'TXD804',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'RAJIV K. SRIVASTAVA   ',
#   'rajiv@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '15'],
#  ['771',
#   'MAJOR PROJECT PART II (TCP) ',
#   'TXD806',
#   'P',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   'PC',
#   'BHUPENDRA SINGH BUTOLA   ',
#   'bsbutola@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '10'],
#  ['772',
#   'STRUCTURE & PHYSICAL PROPERTIE                     ',
#   'TXL211',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'RAJIV K. SRIVASTAVA   ',
#   'rajiv@textile.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '120',
#   '125'],
#  ['773',
#   'YARN MANUFACTURE I                                 ',
#   'TXL221',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'DIPAYAN DAS   ',
#   'dipayan@textile.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '120',
#   '109'],
#  ['774',
#   'FABRIC MANUFACTURE I                               ',
#   'TXL231',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'ABHIJIT MAJUMDAR   ',
#   'majumdar@textile.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '120',
#   '119'],
#  ['775',
#   'TECH. OF TEXT. PREPARATION & F                     ',
#   'TXL241',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'KUSHAL SEN   ',
#   'kushal@textile.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '120',
#   '129'],
#  ['776',
#   'EVALUATION OF TEXTILE MATERIAL                     ',
#   'TXL361',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'DC',
#   'APURBA DAS   ',
#   'apurba@textile.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '120',
#   '92'],
#  ['777',
#   'THEORY OF TEXTILE STRUCTURES                       ',
#   'TXL371',
#   'C',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   'DC',
#   'S.M. ISHTIAQUE   ',
#   'ishtiaque@textile.iitd.ac.in',
#   'TWF 08:00-09:00',
#   '',
#   '',
#   '120',
#   '123'],
#  ['778',
#   'SPECIALITY YARNS AND FABRICS                       ',
#   'TXL372',
#   'J',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'DC',
#   'B.K.BEHERA   ',
#   'behera@textile.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '120',
#   '97'],
#  ['779',
#   'ADVANCED MATERIALS CHARACTERIZATION TECHNIQUES     ',
#   'TXL714',
#   'P',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   'PC',
#   'ASHWINI K. AGRAWAL   ',
#   'ashwini@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '75',
#   '40'],
#  ['780',
#   'TECHNOLOGY OF SOLUTION SPUN FIBRES                 ',
#   'TXL715',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'MANJEET JASSAL   ',
#   'manjeet@textile.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '75',
#   '17'],
#  ['781',
#   'MECHANICS OF SPINNING MACHINES                     ',
#   'TXL725',
#   'A',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'R.S. RENGASAMY   ',
#   'rsr@textile.iitd.ac.in',
#   'MTh 08:00-09:30',
#   '',
#   '',
#   '40',
#   '18'],
#  ['782',
#   'SC. & APP. OF NANOTEC. IN TEX.                     ',
#   'TXL740',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'MANGALA JOSHI   ',
#   'mangala@textile.iitd.ernet.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '65',
#   '77'],
#  ['783',
#   'ADVANCES IN FINISHING OF TEXTILES                  ',
#   'TXL748',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PC',
#   'DEEPTI GUPTA   ',
#   'deepti@textile.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '40',
#   '30'],
#  ['784',
#   'SUSTAINABLE CHEMICAL PROCESSING OF TEXTILES        ',
#   'TXL754',
#   'B',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   'PC',
#   'SAMRAT MUKHOPADHYAY   ',
#   'samrat@textile.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '40',
#   '11'],
#  ['785',
#   'TEXTILE AUXILIARIES                                ',
#   'TXL756',
#   'J',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'BHUPENDRA SINGH BUTOLA   ',
#   'bsbutola@textile.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '65',
#   '13'],
#  ['786',
#   'DE. & MANUF. OF TEXT. STR. CO.                     ',
#   'TXL766',
#   'B',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'BIPIN  KUMAR ',
#   'bipin@textile.iitd.ac.in',
#   'MTh 09:30-11:00',
#   '',
#   '',
#   '65',
#   '69'],
#  ['787',
#   'ELECTRONICS AND CONTROLS FOR TEXTILEINDUSTRY       ',
#   'TXL771',
#   'J',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   'PE',
#   'ANKUR GUPTA   ',
#   'ankurgupta@care.iitd.ac.in',
#   'MTW 12:00-13:00',
#   '',
#   '',
#   '65',
#   '54'],
#  ['788',
#   'TECHNICAL TEXTILES                                 ',
#   'TXL775',
#   'D',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'R.ALAGIRUSAMY   ',
#   'rasamy@textile.iitd.ac.in',
#   'TWF 09:00-10:00',
#   '',
#   '',
#   '65',
#   '57'],
#  ['789',
#   'PRODUCT DESIGN AND DEVELOPMENT                     ',
#   'TXL777',
#   'H',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'R. CHATTOPADHYAY   ',
#   'rchat@textile.iitd.ac.in',
#   'M 11:00-12:00',
#   '',
#   '',
#   '65',
#   '27'],
#  ['790',
#   'PRODUCTION & OPERATIONS MGMT                       ',
#   'TXL782',
#   'F',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   'PE',
#   'S.M. ISHTIAQUE   ',
#   'ishtiaque@textile.iitd.ac.in',
#   'TWF 11:00-12:00',
#   '',
#   '',
#   '65',
#   '53'],
#  ['791',
#   'DESIGN OF EXPER. & STAT. TECH.                     ',
#   'TXL783',
#   'E',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   '',
#   'AMIT RAWAL   ',
#   'arawal@textile.iitd.ac.in',
#   'TWF 10:00-11:00',
#   '',
#   '',
#   '65',
#   '71'],
#  ['792',
#   'MANUFACTURED FIBRE TECHNO. LAB                     ',
#   'TXP212',
#   'C',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'DC',
#   'BHUVANESH GUPTA   ',
#   'bgupta@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '97'],
#  ['793',
#   'YARN MANUFACTURE LABORATORYI                       ',
#   'TXP221',
#   'E',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'DC',
#   'R. CHATTOPADHYAY   ',
#   'rchat@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '108'],
#  ['794',
#   'FABRIC MANUFACTURE LAB.   I                        ',
#   'TXP231',
#   'B',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'DC',
#   'ABHIJIT MAJUMDAR   ',
#   'majumdar@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '112'],
#  ['795',
#   'TECH. OF TEX. PRE. & FIN. LAB.                     ',
#   'TXP241',
#   'F',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   'DC',
#   'MD. S. WAZED ALI   ',
#   'wazed@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '117'],
#  ['796',
#   'EVALUATION OF TEXTILES LAB                         ',
#   'TXP361',
#   'D',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'DC',
#   'APURBA DAS   ',
#   'apurba@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '92'],
#  ['797',
#   'Fibre Production and Post Spinning Operation Laboratory ',
#   'TXP716',
#   'F',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   'PE',
#   'MANGALA JOSHI   ',
#   'mangala@textile.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '65',
#   '17'],
#  ['798',
#   'MECHANICS OF SPINNING MACHINES LAB                 ',
#   'TXP725',
#   'P',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'PC',
#   'R.S. RENGASAMY   ',
#   'rsr@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '40',
#   '18'],
#  ['799',
#   'TEXTILE PREPARATION AND FINISHING LAB              ',
#   'TXP748',
#   'P',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   'PC',
#   'JAVED NABIBAKSHA SHEIKH   ',
#   'jnsheikh@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '25',
#   '17'],
#  ['800',
#   'EVALUATION OF TEXTILE MATERIALS                    ',
#   'TXP761',
#   'C',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   'PC',
#   'R.ALAGIRUSAMY   ',
#   'rasamy@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '75',
#   '19'],
#  ['801',
#   'SEMINAR COURSE 2                                   ',
#   'TXQ302',
#   'P',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'KUSHAL SEN   ',
#   'kushal@textile.iitd.ac.in',
#   '',
#   '',
#   '',
#   '120',
#   '128'],
#  ['802',
#   'Micromechanics of Fracture ',
#   'APV707',
#   'X',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'S. PRADYUMNA   ',
#   'pradyum@am.iitd.ac.in',
#   '',
#   '',
#   '',
#   '30',
#   '0'],
#  ['803',
#   'Global Political Economy ',
#   'HSV319',
#   'X',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   '',
#   'JAYAN JOSE THOMAS   ',
#   'jayan@hss.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '0'],
#  ['804',
#   'PROFE. ETHICS &SOCIAL RESP. 2                      ',
#   'NEN101',
#   'P',
#   0.5,
#   0.0,
#   0.0,
#   1.0,
#   '',
#   'SANGEETA KOHLI   ',
#   'skohli@mech.iitd.ernet.in',
#   '',
#   '',
#   '',
#   '1000',
#   '910'],
#  ['805',
#   'LANGUAGE & WRITING SKILL 2                         ',
#   'NLN101',
#   'P',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   '',
#   'ARJUN GHOSH   ',
#   'arjunghosh@hss.iitd.ac.in',
#   '',
#   '',
#   '',
#   '100',
#   '916']]
