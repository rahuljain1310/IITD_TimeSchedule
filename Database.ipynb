# %%
import psycopg2 as ps
conn = ps.connect("dbname=postgres user=postgres password=postgres")
cur = conn.cursor()

# %%
cur.execute("Select * from CourseDetails;")
cur.fetchall()
# Out:
# [(1,
#   'AMD310',
#   'MINI PROJECT (AM)                                  ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   30,
#   7),
#  (2,
#   'AMD811',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   30,
#   0),
#  (3,
#   'AMD812',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   31),
#  (4,
#   'AMD813',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   30,
#   1),
#  (5,
#   'AMD814',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   4),
#  (6,
#   'AMD895',
#   'MAJOR PROJECT                                      ',
#   'P',
#   '',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   30,
#   2),
#  (7,
#   'AMD897',
#   'MINOR PROJECT                                      ',
#   'X',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   25),
#  (8,
#   'AML702',
#   'APPLIED COMPUTATIONAL METHOD                       ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   100,
#   36),
#  (9,
#   'AML706',
#   'FINITE ELEMENT METHODS & ITS APPL.TO MARINE STRU.  ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   32),
#  (10,
#   'AML731',
#   'APPLIED ELASTICITY                                 ',
#   'X',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   9),
#  (11,
#   'AML793',
#   'SHIP DYNAMICS                                      ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   25),
#  (12,
#   'AML795',
#   'SUBMARINE DESIGN                                   ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   25),
#  (13,
#   'AML831',
#   'THEORY OF PLATES AND SHELLS                        ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   21),
#  (14,
#   'AML832',
#   'APPLICATIONS OF THEORY OF PLATES AND SHELLS        ',
#   'A',
#   '',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   50,
#   29),
#  (15,
#   'AML835',
#   'MECHANICS OF COMPOSITE MATERIALS                   ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   20),
#  (16,
#   'AMP776',
#   'PRODUCT DESIGN PROJECT 1                           ',
#   'F',
#   '',
#   4.0,
#   2.0,
#   0.0,
#   4.0,
#   60,
#   20),
#  (17,
#   'APL100',
#   'ENGINEERING MECHANICS                              ',
#   'A',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   250,
#   469),
#  (18,
#   'APL102',
#   'INTR.TO MATERIAL SC. & ENGG.                       ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   300,
#   131),
#  (19,
#   'APL105',
#   'MECHANICS OF SOLIDS AND FLUIDS                     ',
#   'A',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   150,
#   122),
#  (20,
#   'APL300',
#   'COMPUTATIONAL MECHANICS                            ',
#   'A',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   100,
#   31),
#  (21,
#   'APL705',
#   'FINITE ELEMENT METHOD                              ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   100,
#   53),
#  (22,
#   'APL711',
#   'ADVANCED FLUID MECHANICS                           ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   12),
#  (23,
#   'APL713',
#   'TURBULENCE AND ITS MODELING                        ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   20),
#  (24,
#   'APL720',
#   'COMPUTATIONAL FLUID DYNAMICS                       ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   50,
#   22),
#  (25,
#   'APL750',
#   'MODERN ENGINEERING MATERIALS                       ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   13),
#  (26,
#   'APL767',
#   'ENGG. FAILURE ANALYSIS & PREV.                     ',
#   'AC',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   15),
#  (27,
#   'APL774',
#   'MODELING AND ANALYSIS                              ',
#   'AA',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   9),
#  (28,
#   'APL796',
#   'ADVANCED SOLID MECHANICS                           ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   19),
#  (29,
#   'APL871',
#   'PRODUCT RELIABILITY & MAINTENANCE                  ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   33),
#  (30,
#   'APV707',
#   'Micromechanics of Fracture ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   0),
#  (31,
#   'ASD882',
#   'PROJECT II                                         ',
#   'Q',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   12,
#   12),
#  (32,
#   'ASL340',
#   'Fundamentals of Weather and Climate ',
#   'F',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   80,
#   68),
#  (33,
#   'ASL350',
#   'INTRODUCTION TOOCEANOGRAPHY                        ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   80,
#   71),
#  (34,
#   'ASL360',
#   'THE EARTH`S ATMOSPHERE:PHYSICAL PRINCIPLES         ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   80,
#   80),
#  (35,
#   'ASL734',
#   'DYNAMICS OF THE ATMOSPHERE                         ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   24),
#  (36,
#   'ASL736',
#   'SCIENCE OF CLIMATE CHANGE                          ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   25,
#   21),
#  (37,
#   'ASL737',
#   'PHYSICAL AND DYNAMICAL OCEANOGRAPHY                ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   25,
#   14),
#  (38,
#   'ASL738',
#   'NUMERICAL MODELING OF THE ATMOSPHERE AND OCEAN     ',
#   'AD',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   16,
#   14),
#  (39,
#   'ASL751',
#   'DISPERSION OF AIR POLLUTANTS                       ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   21),
#  (40,
#   'ASL754',
#   'CLOUD PHYSICS                                      ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   7),
#  (41,
#   'ASL760',
#   'RENEWABLE ENERGY METEOROLOGY                       ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   25,
#   5),
#  (42,
#   'ASP820',
#   'ADVANCED DATA ANALYSIS FOR WEATHER AND CLIMATE     ',
#   'K',
#   '',
#   3.0,
#   1.0,
#   0.0,
#   4.0,
#   15,
#   12),
#  (43,
#   'BBD451',
#   'MAJOR PROJECT PART 1 (BB1)                         ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   30,
#   4),
#  (44,
#   'BBD452',
#   'MAJOR PROJECT PART 2 (BB1)                         ',
#   'Q',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (45,
#   'BBD851',
#   'MAJOR PROJECT PART 1 (BB5)                         ',
#   'Q',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   0),
#  (46,
#   'BBD852',
#   'MAJOR PROJECT PART 2 (BB5)                         ',
#   'Q',
#   '',
#   14.0,
#   0.0,
#   0.0,
#   28.0,
#   60,
#   5),
#  (47,
#   'BBD853',
#   'MAJOR PROJECT PART 1 (BB5)                         ',
#   'Q',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   0),
#  (48,
#   'BBD854',
#   'MAJOR PROJECT PART 2 (BB5)                         ',
#   'Q',
#   '',
#   16.0,
#   0.0,
#   0.0,
#   32.0,
#   60,
#   11),
#  (49,
#   'BBD895',
#   'MAJOR PROJECT                                      ',
#   'Q',
#   '',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   60,
#   11),
#  (50,
#   'BBL341',
#   'ENVIRONMENTAL BIOTECHNOLOGY                        ',
#   'H',
#   'DE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   13),
#  (51,
#   'BBL431',
#   'BIOPROCESS TECHNOLOGY                              ',
#   'J',
#   'DC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   100,
#   77),
#  (52,
#   'BBL432',
#   'FLUID SOLID SYSTEMS                                ',
#   'H',
#   'DC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   100,
#   56),
#  (53,
#   'BBL433',
#   'ENZYME SCIENCE AND ENGINEERING                     ',
#   'D',
#   'DC',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   100,
#   55),
#  (54,
#   'BBL434',
#   'BIOINFORMATICS                                     ',
#   'C',
#   'DC',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   100,
#   73),
#  (55,
#   'BBL443',
#   'MODELING & SIMULATION OF BIO.                      ',
#   'J',
#   'DE',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   100,
#   13),
#  (56,
#   'BBL445',
#   'MEMBRANE APPLICATIONS IN BIO.                      ',
#   'E',
#   'DE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   33),
#  (57,
#   'BBL736',
#   'DYNAMICS OF MICROBIAL SYSTEMS                      ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   27),
#  (58,
#   'BBL740',
#   'PLANT CELL TECHNOLOGY                              ',
#   'K',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   60,
#   19),
#  (59,
#   'BBL742',
#   'BIOLOGICAL WASTE TREATMENT                         ',
#   'D',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   60,
#   32),
#  (60,
#   'BBL745',
#   'COMBINATORIAL BIOTECHNOLOGY                        ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   25),
#  (61,
#   'BBL746',
#   'CURRENT TOPICS IN BIOCHEMICALENGINEERING AND BIOTE ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   15),
#  (62,
#   'BBL747',
#   'BIONANOTECHNOLOGY                                  ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   22),
#  (63,
#   'BBL749',
#   'CANCER CELL BIOLOGY                                ',
#   'F',
#   '',
#   4.5,
#   3.0,
#   0.0,
#   3.0,
#   60,
#   36),
#  (64,
#   'BBQ301',
#   'SEMINAR COURSE   I                                 ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   20,
#   20),
#  (65,
#   'BBQ302',
#   'SEMINAR COURSE   II                                ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   20,
#   16),
#  (66,
#   'BBQ303',
#   'SEMINAR COURSE   III                               ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   20,
#   20),
#  (67,
#   'BED800',
#   'MAJOR PROJECT                                      ',
#   'P',
#   '',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   10,
#   1),
#  (68, 'BMD802', 'Major Project 2 ', 'X', 'PC', 12.0, 0.0, 0.0, 24.0, 60, 7),
#  (69,
#   'BML735',
#   'BIOMEDICAL SIGNAL AND IMAGE PR                     ',
#   'AD',
#   'PE',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   60,
#   35),
#  (70,
#   'BML737',
#   'APPLICATIONS OF MATHEMATICS IN BIOMEDICAL ENG.     ',
#   'D',
#   'PC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   60,
#   16),
#  (71,
#   'BML740',
#   'BIOMEDICAL INSTRUMENTATION                         ',
#   'E',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   17),
#  (72,
#   'BML750',
#   'POINT OF CARE MEDICAL DIAG DEV                     ',
#   'F',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   5),
#  (73,
#   'BML760',
#   'BIOMEDICAL ETHICS, SAFETY AND REGULATORY AFFAIRS   ',
#   'B',
#   'PC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   60,
#   9),
#  (74,
#   'BML771',
#   'Orthopaedic Device Design ',
#   'H',
#   'PE',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (75,
#   'BML820',
#   'BIOMATERIALS                                       ',
#   'J',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (76,
#   'BML860',
#   'NANOMEDICINE                                       ',
#   'K',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   9),
#  (77,
#   'BMP743',
#   'BASIC BIOMEDICAL LABORATORY                        ',
#   'X',
#   'PC',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   60,
#   7),
#  (78,
#   'BSD895',
#   'MAJOR PROJECT(MSR)                                 ',
#   'P',
#   '',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   60,
#   4),
#  (79,
#   'CHD771',
#   'MINOR PROJECT                                      ',
#   'Q',
#   'PC',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   0),
#  (80,
#   'CHD871',
#   'MAJOR PROJECT PART 1 (CM)                          ',
#   'Q',
#   'PC',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   2),
#  (81,
#   'CHD872',
#   'MAJOR PROJECT PART II (CM)                         ',
#   'Q',
#   'PC',
#   14.0,
#   0.0,
#   0.0,
#   28.0,
#   60,
#   1),
#  (82,
#   'CHD873',
#   'MAJOR PROJECT PART 1 (CM)                          ',
#   'Q',
#   'PC',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   0),
#  (83,
#   'CHD874',
#   'MAJOR PROJECT PART 2 (CM)                          ',
#   'Q',
#   'PC',
#   16.0,
#   0.0,
#   0.0,
#   32.0,
#   60,
#   0),
#  (84,
#   'CLD411',
#   'B. TECH. PROJECT                                   ',
#   'Q',
#   'DC',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   100,
#   13),
#  (85,
#   'CLD412',
#   'MAJOR PROJECT IN ENERGY & ENV.                     ',
#   'Q',
#   'DE',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   100,
#   5),
#  (86,
#   'CLD413',
#   'MAJOR PROJECT IN COMPLEX FLUID                     ',
#   'Q',
#   'DE',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   100,
#   0),
#  (87,
#   'CLD414',
#   'MAJOR PROJ. IN P.E, MOD. & OP.                     ',
#   'Q',
#   'DE',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   100,
#   0),
#  (88,
#   'CLD415',
#   'MAJOR PROJ IN BIOP. & FINE CH.                     ',
#   'Q',
#   'DE',
#   5.0,
#   0.0,
#   0.0,
#   10.0,
#   100,
#   3),
#  (89,
#   'CLD771',
#   'MINOR PROJECT                                      ',
#   'Q',
#   'PC',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   32),
#  (90,
#   'CLD781',
#   'MAJOR PROJECT   I                                  ',
#   'Q',
#   'PC',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   60,
#   1),
#  (91,
#   'CLD782',
#   'MAJOR PROJECT   II                                 ',
#   'Q',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   15),
#  (92,
#   'CLD880',
#   'MINOR PROJECT                                      ',
#   'Q',
#   'PC',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   42),
#  (93,
#   'CLD881',
#   'MAJOR PROJECT PARTI                                ',
#   'Q',
#   'PC',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   60,
#   2),
#  (94,
#   'CLD882',
#   'MAJOR PROJECT PARTII                               ',
#   'Q',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   39),
#  (95,
#   'CLL121',
#   'CHEMICAL ENGG. THERMODYNAMICS                      ',
#   'A',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   143),
#  (96,
#   'CLL122',
#   'CHEMICAL REACTION ENGG I                           ',
#   'D',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   178),
#  (97,
#   'CLL231',
#   'FLUID MECHS. FOR CHEM. ENGINEE                     ',
#   'F',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   194),
#  (98,
#   'CLL251',
#   'HEAT TRANSFER FOR CHEMICAL ENG                     ',
#   'B',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   187),
#  (99,
#   'CLL271',
#   'INTRO TO INDUSTRIAL BIOTECH.                       ',
#   'D',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   108),
#  (100,
#   'CLL352',
#   'MASS TRANSFER II                                   ',
#   'B',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   118),
#  (101,
#   'CLL361',
#   'INSTRUMENTATION AND AUTOMATION                     ',
#   'C',
#   'DC',
#   2.5,
#   1.0,
#   0.0,
#   3.0,
#   100,
#   106),
#  (102,
#   'CLL371',
#   'CHEM. PROCESS TECH.& ECONOMICS                     ',
#   'E',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   127),
#  (103,
#   'CLL402',
#   'PROCESS PLANT DESIGN                               ',
#   'D',
#   'DE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   12),
#  (104,
#   'CLL475',
#   'SAFETY & HAZARDS IN PROC. IND.                     ',
#   'B',
#   'DE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   25),
#  (105,
#   'CLL722',
#   'ELECTROCHEM. CONV. & STO. DEV.                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   36),
#  (106,
#   'CLL727',
#   'HETERO. CATALYSIS & CATA. REA.                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   41),
#  (107,
#   'CLL731',
#   'ADVANCED TRANSPORT PHENOMENA                       ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   100),
#  (108,
#   'CLL732',
#   'ADV. CHE. ENGG. THERMODYNAMICS                     ',
#   'AA',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   20),
#  (109,
#   'CLL733',
#   'INDUSTRIAL MULTIPHASE REACTORS                     ',
#   'H',
#   'PC,DE,PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   110,
#   115),
#  (110,
#   'CLL766',
#   'INTERFACIAL ENGINEERING                            ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   61),
#  (111,
#   'CLL767',
#   'STRUCTURES & PROP. OF POLYMERS                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   22),
#  (112,
#   'CLL768',
#   'FUNDAMENTALS OF COMP. FLUID DY                     ',
#   'F',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   30,
#   12),
#  (113,
#   'CLL771',
#   'INTRODUCTION TO COMPLEX FLUIDS                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   32),
#  (114,
#   'CLL772',
#   'TRANS. PHEN. IN COMPLEX FLUIDS                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   12),
#  (115,
#   'CLL779',
#   'MOL. BIOTECH. & IN VITRO DIAG.                     ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   12),
#  (116,
#   'CLL782',
#   'PROCESS OPTIMIZATION                               ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   34),
#  (117,
#   'CLL786',
#   'FINE CHEMICALS TECHNOLOGY                          ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   56),
#  (118,
#   'CLL788',
#   'Process Data Analytics ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   56),
#  (119,
#   'CLL793',
#   'MEMBRANE SCIENCE & ENGINEERING                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   50),
#  (120,
#   'CLP302',
#   'CHEMICAL ENGINEERING LAB   II                      ',
#   'E',
#   'DC',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   100,
#   159),
#  (121,
#   'CLP704',
#   'TECHNICAL COMMUNICATION FOR CHEMICAL ENGINEERS     ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   60,
#   66),
#  (122,
#   'CLQ301',
#   'SEMINAR COURSE   I                                 ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   35,
#   43),
#  (123,
#   'CLQ302',
#   'SEMINAR COURSE   II                                ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   35,
#   33),
#  (124,
#   'CLV797',
#   'RECENT  ADV. IN CHEMICAL ENGG.                     ',
#   'X',
#   '',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (125,
#   'CMD641',
#   'PROJECT PART II                                    ',
#   'P',
#   '',
#   10.0,
#   0.0,
#   0.0,
#   20.0,
#   60,
#   49),
#  (126,
#   'CMD807',
#   'MAJOR  PROJECT PART   II                           ',
#   'P',
#   '',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   30,
#   11),
#  (127,
#   'CML100',
#   'INTRODUCTION TO CHEMISTRY                          ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   200,
#   461),
#  (128,
#   'CML521',
#   'MOLECULAR THERMODYNAMICS                           ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   55),
#  (129,
#   'CML522',
#   'CHEMICAL DYNA. & SURFACE CHEM.                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   54),
#  (130,
#   'CML523',
#   'ORGANIC SYNTHESIS                                  ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   55),
#  (131,
#   'CML524',
#   'TRAN. & INNER TRAN. METAL CHE.                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   54),
#  (132,
#   'CML525',
#   'BASIC ORGANOMETALIC CHEMISTRY                      ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   54),
#  (133,
#   'CML526',
#   'STR. & FUNC. OF CELLULAR BIOM.                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   54),
#  (134,
#   'CML665',
#   'BIOPHYSICAL CHEMISTRY                              ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (135,
#   'CML673',
#   'Bio organic and Medicinal chemistry                ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   7),
#  (136, 'CML682', 'Inorganic Polymers ', 'E', 'PC', 3.0, 3.0, 0.0, 0.0, 60, 30),
#  (137,
#   'CML724',
#   'SYNTHESIS OF INDUSTRIALLY IMPO                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   30),
#  (138,
#   'CML729',
#   'MATERIAL CHARACTERIZATION                          ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   28),
#  (139,
#   'CML737',
#   'APPLIED SPECTROSCOPY                               ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   31),
#  (140,
#   'CML738',
#   'APPLICATIONS OF P BLOCK ELEMEN                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   16),
#  (141,
#   'CML739',
#   'APPLIED BIOCATALYSIS                               ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   28),
#  (142,
#   'CML740',
#   'CHEMISTRY OF HETEROCYCLIC COMP                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   33),
#  (143,
#   'CML801',
#   'MOLECULAR MODELLING AND SIMULA                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   21),
#  (144,
#   'CMP100',
#   'CHEMISTRY LABORATORY                               ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   1000,
#   458),
#  (145,
#   'CMP521',
#   'LAB III                                            ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   240,
#   53),
#  (146,
#   'CMP522',
#   'LAB IV                                             ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   240,
#   53),
#  (147,
#   'CMP728',
#   'INSTRUMENTATION LABORATORY                         ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   8),
#  (148,
#   'COD310',
#   'MINI PROJECT                                       ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   40,
#   27),
#  (149,
#   'COD492',
#   'B.TECH PROJECT PART 1                              ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   120,
#   4),
#  (150,
#   'COD494',
#   'B.TECH PROJECT PART 2                              ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   120,
#   40),
#  (151,
#   'COD891',
#   'MINOR PROJECT                                      ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   80,
#   51),
#  (152,
#   'COD892',
#   'M.TECH PROJECT PARTI                               ',
#   'P',
#   '',
#   7.0,
#   0.0,
#   0.0,
#   14.0,
#   40,
#   0),
#  (153,
#   'COD893',
#   'M.TECH PROJECT PARTII                              ',
#   'P',
#   '',
#   14.0,
#   0.0,
#   0.0,
#   28.0,
#   50,
#   43),
#  (154,
#   'COD895',
#   'MSR PROJECT                                        ',
#   'P',
#   '',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   30,
#   5),
#  (155,
#   'COL100',
#   'INTRO. TO COMPUTER SCIENCE                         ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   600,
#   513),
#  (156,
#   'COL106',
#   'DATA STRUCTURES AND ALGORITHMS                     ',
#   'F',
#   '',
#   5.0,
#   3.0,
#   0.0,
#   4.0,
#   180,
#   206),
#  (157,
#   'COL216',
#   'COMPUTER ARCHITECTURE                              ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   125,
#   113),
#  (158,
#   'COL226',
#   'PROGRAMMING LANGUAGES                              ',
#   'F',
#   '',
#   5.0,
#   3.0,
#   0.0,
#   4.0,
#   140,
#   127),
#  (159,
#   'COL331',
#   'OPERATING SYSTEMS                                  ',
#   'E',
#   '',
#   5.0,
#   3.0,
#   0.0,
#   4.0,
#   120,
#   121),
#  (160,
#   'COL352',
#   'INTRO TO AUTOMATA & TH. OF CO.                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   125,
#   120),
#  (161,
#   'COL362',
#   'INTRO. TO DATABASE MGMT. SYST.                     ',
#   'C',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   150,
#   115),
#  (162,
#   'COL380',
#   'INTRO. TO PARALLEL & DIS. PRO.                     ',
#   'J',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   120,
#   122),
#  (163,
#   'COL632',
#   'INTRODUCTION TO DATA BASESYSTEMS                   ',
#   'C',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   30,
#   15),
#  (164,
#   'COL633',
#   'RESOURCE MANAGEMENT IN COMPUTER SYSTEMS            ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   30,
#   3),
#  (165,
#   'COL724',
#   'ADVANCED COMPUTER NETWORKS                         ',
#   'D',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   40,
#   21),
#  (166,
#   'COL726',
#   'NUMERICAL ALGORITHMS                               ',
#   'M',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   70,
#   53),
#  (167,
#   'COL729',
#   'COMPILER OPTIMIZATION                              ',
#   'A',
#   '',
#   4.5,
#   3.0,
#   0.0,
#   3.0,
#   45,
#   11),
#  (168,
#   'COL740',
#   'SOFTWARE ENGINEERING                               ',
#   'H',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   95,
#   64),
#  (169,
#   'COL758',
#   'ADVANCED ALGORITHMS                                ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   50,
#   32),
#  (170,
#   'COL772',
#   'NATURAL LANGUAGE PROCESSING                        ',
#   'AA',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   30,
#   45),
#  (171,
#   'COL774',
#   'MACHINE LEARNING                                   ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   130,
#   137),
#  (172,
#   'COL781',
#   'COMPUTER GRAPHICS                                  ',
#   'K',
#   '',
#   4.5,
#   3.0,
#   0.0,
#   3.0,
#   90,
#   53),
#  (173,
#   'COL786',
#   'ADVANCED FUNCTIONAL BRAIN IMG.                     ',
#   'AC',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   30,
#   20),
#  (174,
#   'COL812',
#   'SYSTEM LEVEL DESIGN& MODELLING                     ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   6),
#  (175,
#   'COL863',
#   'SPL. TOPICS IN THEO. COMP. SC. ',
#   'AC',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   25),
#  (176,
#   'COL864',
#   'SPL. TOPICS IN ARTIFICIAL INT.                     ',
#   'AA',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   23),
#  (177,
#   'COL872',
#   'SPL. TOPICS IN CRYPTOGRAPHY                        ',
#   'AD',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   30),
#  (178,
#   'COL886',
#   'Special Topics in Operating Systems ',
#   'AC',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   15,
#   6),
#  (179,
#   'COP290',
#   'DESIGN PRACTICES                                   ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   120,
#   135),
#  (180,
#   'COP315',
#   'EMBEDDED SYSTEM DESIGN PROJECT                     ',
#   'P',
#   '',
#   4.0,
#   0.0,
#   1.0,
#   6.0,
#   100,
#   56),
#  (181,
#   'COP701',
#   'SOFTWARE SYSTEMS LABORATORY                        ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   40,
#   2),
#  (182,
#   'COQ301',
#   'SEMINAR COURSE   I                                 ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   60,
#   22),
#  (183,
#   'COQ302',
#   'SEMINAR COURSE   II                                ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   60,
#   29),
#  (184,
#   'COQ303',
#   'SEMINAR COURSE   III                               ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   60,
#   19),
#  (185,
#   'COQ304',
#   'SEMINAR COURSE   IV                                ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   60,
#   24),
#  (186,
#   'COS310',
#   'INDEPENDENT STUDY (CS)                             ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   30,
#   13),
#  (187,
#   'COS799',
#   'INDEPENDENT STUDY                                  ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   30,
#   6),
#  (188,
#   'COV878',
#   'SPECIAL MODULE IN MACHINE LEA.                     ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   60,
#   27),
#  (189,
#   'COV880',
#   'SPECIAL MODULE IN PARALLEL CO.                     ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   7),
#  (190,
#   'COV883',
#   'SPL. MODULE IN THEO. COMP. SC.                     ',
#   'P',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   60,
#   7),
#  (191,
#   'COV884',
#   'SPL. MODULE IN ARTIFICIAL INT.                     ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   7),
#  (192,
#   'COV887',
#   'SPL. MODULE IN HIGH SPEED NET.                     ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   22),
#  (193,
#   'COV888',
#   'SPL. MODULE IN DATABASE SYST.                      ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   8),
#  (194,
#   'CRD802',
#   'MINOR PROJECT                                      ',
#   'A',
#   'PC',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   25),
#  (195,
#   'CRD811',
#   'MAJOR PROJECT PART I                               ',
#   'Q',
#   'PC',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   1),
#  (196,
#   'CRD812',
#   'MAJOR PROJECT PART 2                               ',
#   'Q',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   22),
#  (197,
#   'CRD814',
#   'MAJOR PROJECT III                                  ',
#   'Q',
#   'PC',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   1),
#  (198,
#   'CRL702',
#   'ARCHITECTURES AND ALGORITHMS FOR DSP SYSTEMS       ',
#   'E',
#   'PC',
#   4.0,
#   2.0,
#   0.0,
#   4.0,
#   40,
#   27),
#  (199,
#   'CRL704',
#   'SENSOR ARRAY SIGNAL PROCESSING                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   15),
#  (200,
#   'CRL706',
#   'SONARS                                             ',
#   'J',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   7),
#  (201,
#   'CRL712',
#   'RF AND MICROWAVE ACTIVE CIRCUITS                   ',
#   'A',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   26),
#  (202,
#   'CRL722',
#   'RF AND MICROWAVE SOLID STATE DEVICES               ',
#   'H',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   10),
#  (203,
#   'CRL724',
#   'RF AND MICROWAVE MEASUREMENT SYSTEM TECHNIQUES     ',
#   'B',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   27),
#  (204,
#   'CRL732',
#   'SELECTED TOPICS IN RFDT II                         ',
#   'D',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (205,
#   'CRV742',
#   'SPECIAL MODULE IN RADIO FREQUENCY DESIGN & TECH. I ',
#   'X',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   20,
#   20),
#  (206,
#   'CSD411',
#   'MAJOR PROJECT PART 1 (CS)                          ',
#   'P',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   40,
#   0),
#  (207,
#   'CSD853',
#   'MAJOR PROJECT PART 1 (CO)                          ',
#   'P',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   40,
#   0),
#  (208,
#   'CVC772',
#   'SEMINAR IN CONSTRUCTION TECHNO                     ',
#   'R',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   30),
#  (209,
#   'CVD411',
#   'BTECH PROJECT PART 1                               ',
#   'P',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   120,
#   30),
#  (210,
#   'CVD412',
#   'BTECH PROJECT PART 2                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   120,
#   15),
#  (211,
#   'CVD700',
#   'MINOR PROJECT                                      ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   5,
#   0),
#  (212,
#   'CVD710',
#   'MINOR PROJECT                                      ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   5,
#   0),
#  (213,
#   'CVD720',
#   'MAJOR THESIS PART I                                ',
#   'M',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   24,
#   0),
#  (214,
#   'CVD721',
#   'MAJOR THESIS PART II                               ',
#   'M',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   25,
#   6),
#  (215,
#   'CVD756',
#   'MINOR PROJECT IN STRUCTURAL ENGINEERING            ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   50,
#   0),
#  (216,
#   'CVD757',
#   'MAJOR PROJECT PART I (CES)                         ',
#   'P',
#   '',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   50,
#   0),
#  (217,
#   'CVD758',
#   'MAJOR PROJECT PART II (CES)                        ',
#   'P',
#   '',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   50,
#   17),
#  (218,
#   'CVD772',
#   'MAJOR PROJECT PART I (CEC)                         ',
#   'P',
#   '',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   50,
#   0),
#  (219,
#   'CVD773',
#   'MAJOR PROJECT PART II (CEC)                        ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   24),
#  (220,
#   'CVD776',
#   'MINOR PROJECT (CET)                                ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   50,
#   0),
#  (221,
#   'CVD777',
#   'MAJOR PROJECT PART I (CET)                         ',
#   'P',
#   '',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   50,
#   1),
#  (222,
#   'CVD778',
#   'MAJOR PROJECT PART II (CET)                        ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   19),
#  (223,
#   'CVD801',
#   'MAJOR THESIS PART II                               ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   25,
#   8),
#  (224,
#   'CVD810',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   30,
#   2),
#  (225,
#   'CVD811',
#   'MAJOR PROJECT PART II (CEU)                        ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   26,
#   16),
#  (226,
#   'CVD832',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   50,
#   12),
#  (227,
#   'CVD854',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   12),
#  (228,
#   'CVD895',
#   'MSR MAJOR PROJECT                                  ',
#   'P',
#   '',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   30,
#   2),
#  (229,
#   'CVL100',
#   'ENVIRONMENTAL SCIENCE                              ',
#   'C',
#   '',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   500,
#   550),
#  (230,
#   'CVL212',
#   'ENVIRONMENTAL ENGINEERING                          ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   120,
#   97),
#  (231,
#   'CVL222',
#   'SOIL MECHANICS                                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   103),
#  (232,
#   'CVL242',
#   'STRUCTURAL ANALYSIS I                              ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   103),
#  (233,
#   'CVL244',
#   'CONSTRUCTION PRACTICES                             ',
#   'C',
#   '',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   120,
#   95),
#  (234,
#   'CVL261',
#   'INTRO. TO TRANSPORTATION ENGG.                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   100),
#  (235,
#   'CVL281',
#   'HYDRAULICS                                         ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   120,
#   101),
#  (236,
#   'CVL313',
#   'AIR AND NOISE POLLUTION                            ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   41),
#  (237,
#   'CVL342',
#   'STEEL DESIGN                                       ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   99),
#  (238,
#   'CVL381',
#   'DESIGN OF HYDRAULIC STRUCTURES                     ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   120,
#   94),
#  (239,
#   'CVL382',
#   'GROUNDWATER                                        ',
#   'H',
#   '',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   30,
#   43),
#  (240,
#   'CVL422',
#   'ROCK ENGINEERING                                   ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   40),
#  (241,
#   'CVL431',
#   'DESIGN OF FOUN. & RET. STRUCT.                     ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   59,
#   42),
#  (242,
#   'CVL443',
#   'PRESTRESSED CON. & IND. STRUC.                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   50),
#  (243,
#   'CVL482',
#   'WATER POWER ENGINEERING                            ',
#   'X',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   30,
#   32),
#  (244,
#   'CVL702',
#   'GROUND IMPROVEMENT AND GEOSYNTHETICS               ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   12),
#  (245,
#   'CVL703',
#   'GEOENVIRONMENTAL ENGINEERING                       ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   14),
#  (246,
#   'CVL705',
#   'SLOPES AND RETAINING STRUCTURES                    ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   15),
#  (247,
#   'CVL706',
#   'SOIL DYNAMICS AND EARTHQUAKE GEOTECHNICAL ENGG.    ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   13),
#  (248,
#   'CVL712',
#   'SLOPES AND FOUNDATIONS                             ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   15),
#  (249,
#   'CVL713',
#   'ANALYSIS AND DESIGN OF UNDERGROUND STRUCTURES      ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   13),
#  (250,
#   'CVL714',
#   'FIELD EXPLORATION AND GEOTECHNICAL PROCESSES       ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   16),
#  (251,
#   'CVL715',
#   'EXCAVATION METHODS & UNDERGROUND SPACE TECHNOLOGY  ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   13),
#  (252,
#   'CVL721',
#   'SOLID WASTE ENGINEERING                            ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   40),
#  (253,
#   'CVL723',
#   'WASTE WATER ENGINEERING                            ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   24),
#  (254,
#   'CVL724',
#   'ENVIRONMENTAL SYSTEMS ANALYSIS                     ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   41),
#  (255,
#   'CVL727',
#   'ENVIROMENTAL RISK ASSESMENT ',
#   'M',
#   '',
#   3.0,
#   2.0,
#   1.0,
#   0.0,
#   40,
#   10),
#  (256,
#   'CVL728',
#   'ENVIRONMENTAL QUALITY MODELING                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   36),
#  (257,
#   'CVL734',
#   'ADVANCED HYDRAULICS                                ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   15),
#  (258,
#   'CVL735',
#   'FINITE ELEMENT IN WATER RESOU.                     ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   12),
#  (259,
#   'CVL743',
#   'AIRPORT PLANNING AND DESIGN                        ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   10),
#  (260,
#   'CVL746',
#   'PUBLIC TRANSPORTATION SYSTEMS                      ',
#   'L',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   20),
#  (261,
#   'CVL760',
#   'THEORY OF CONCRETE STRUCTURES                      ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   20),
#  (262,
#   'CVL761',
#   'THEORY OF STEEL STRUCTURES                         ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   22),
#  (263,
#   'CVL762',
#   'EARTHQUAKE ANALYSIS AND DESIGN                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   36),
#  (264,
#   'CVL774',
#   'CONSTRUCTION CONTRACT MGMT.                        ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   41),
#  (265,
#   'CVL775',
#   'CONSTRUCTION ECONOMICS AND FI                      ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   50),
#  (266,
#   'CVL776',
#   'CONSTRUCTION PRACTICES AND EQ                      ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   48),
#  (267,
#   'CVL778',
#   'BUILDING SERVICES AND MAINTENA                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   6),
#  (268,
#   'CVL811',
#   'NUMERICAL AND COMPUTER METHODS IN GEOMECHANICS     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   10,
#   0),
#  (269,
#   'CVL830',
#   'GROUNDWATER FLOW AND POLLUTION MODELING            ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   16),
#  (270,
#   'CVL833',
#   'WATER RESOURCES SYSTEMS                            ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   8),
#  (271,
#   'CVL838',
#   'GEOGRAPHIC INFORMATION SYSTEMS                     ',
#   'H',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   50,
#   18),
#  (272,
#   'CVL841',
#   'ADVANCED TRANSPORTATION MODELLING                  ',
#   'H',
#   '',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   10,
#   6),
#  (273,
#   'CVL845',
#   'VISCOELASTIC BEHAVIOR OF BITUM                     ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   5),
#  (274,
#   'CVL847',
#   'TRANSPORTATION ECONOMICS                           ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   23),
#  (275,
#   'CVL849',
#   'TRAFFIC FLOW MODELLING                             ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   6),
#  (276,
#   'CVL850',
#   'TRANSPORTATION LOGISTICS                           ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   12),
#  (277,
#   'CVL861',
#   'ANALYSIS & DESIGN OF M/C FOU.                      ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   20),
#  (278,
#   'CVL863',
#   'General Continuum Mechanics ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   6),
#  (279,
#   'CVL864',
#   'STRUCTURAL HEALTH MONITORING                       ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   18),
#  (280,
#   'CVL865',
#   'Structural Vibration Control ',
#   'D',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   6),
#  (281,
#   'CVL871',
#   'DURABILITY AND REPAIR OF CONCR                     ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   8),
#  (282,
#   'CVL874',
#   'QUALITY AND SAFETY IN CONSTRUC                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   11),
#  (283,
#   'CVL875',
#   'SUSTAINABLE MATERIALS AND GREE                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   31),
#  (284,
#   'CVP222',
#   'SOIL MECHANICS LABORATORY                          ',
#   'E',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   101),
#  (285,
#   'CVP242',
#   'STRUCTURAL ANALYSIS LABORATORY                     ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   100,
#   102),
#  (286,
#   'CVP261',
#   'TRANSPORTATION ENGG. LABORATOR                     ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   101),
#  (287,
#   'CVP281',
#   'HYDRAULICS LABORATORY                              ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   101),
#  (288,
#   'CVP342',
#   'STRUCTURES & MATERIAL LAB                          ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   94),
#  (289,
#   'CVP730',
#   'SIMULATION LABORATORY I                            ',
#   'P',
#   '',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   50,
#   11),
#  (290,
#   'CVP731',
#   'SIMULATION LABORATORY II                           ',
#   'P',
#   '',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   50,
#   11),
#  (291,
#   'CVP756',
#   'STRUCTURAL ENGINEERING LAB                         ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   50,
#   32),
#  (292,
#   'CVP771',
#   'CONSTRUCTION TECHNOLOGY LABORA                     ',
#   'P',
#   '',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   40,
#   17),
#  (293,
#   'CVP800',
#   'GEOENVIRONMENTAL AND GEOTECHNICAL ENGINEERING LAB  ',
#   'R',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   30,
#   11),
#  (294,
#   'CVP810',
#   'ROCK MECHANICS LABORATORY II                       ',
#   'R',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   30,
#   9),
#  (295,
#   'CVQ301',
#   'CIVIL ENGINEERING SEMINAR                          ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   137),
#  (296,
#   'CVS810',
#   'INDEPENDENT STUDY (CEU)                            ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   10,
#   1),
#  (297,
#   'DSD792',
#   'DESIGN PROJECT 1                                   ',
#   'P',
#   'PC',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   20,
#   21),
#  (298,
#   'DSD799',
#   'DESIGN PROJECT                                     ',
#   'P',
#   'PC',
#   4.0,
#   1.0,
#   0.0,
#   6.0,
#   20,
#   17),
#  (299,
#   'DSD802',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   18,
#   6),
#  (300,
#   'DSD892',
#   'INDUSTRY/ RESEARCH DESIGN PRO.                     ',
#   'P',
#   'PC',
#   9.0,
#   0.0,
#   0.0,
#   18.0,
#   20,
#   15),
#  (301,
#   'DSL712',
#   'ELECTRONIC TECH. FOR SIGNAL CONDITIONING & INTERFA ',
#   'E',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   80,
#   37),
#  (302,
#   'DSL714',
#   'INSTRUMENT DESIGN AND SIMULATIONS                  ',
#   'J',
#   'PC',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   20,
#   16),
#  (303,
#   'DSL734',
#   'LASER BASED INSTRUMENTATION                        ',
#   'H',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   16),
#  (304,
#   'DSL737',
#   'DISPLAY DEVICES & TECHNOLOGY                       ',
#   'K',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   20,
#   12),
#  (305,
#   'DSL782',
#   'DESIGN FOR USABILITY                               ',
#   'E',
#   'PE',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   60,
#   33),
#  (306,
#   'DSL811',
#   'SELECTED TOPICS IN INSTRUMENTATION I               ',
#   'F',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   9),
#  (307,
#   'DSP704',
#   'INSTRUMENT TECHNOLOGY LABORATORY II                ',
#   'P',
#   'PC',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   20,
#   16),
#  (308,
#   'DSP711',
#   'COMP.  AIDED PRODUCT DETAILING                     ',
#   'J',
#   'PC',
#   3.0,
#   1.0,
#   0.0,
#   4.0,
#   40,
#   22),
#  (309,
#   'DSP722',
#   'APPLIED ERGONOMICS                                 ',
#   'A',
#   'PC',
#   2.0,
#   1.0,
#   0.0,
#   2.0,
#   40,
#   33),
#  (310,
#   'DSP741',
#   'PRODUCT INTERFACE & DESIGN                         ',
#   'B',
#   'PC',
#   2.0,
#   1.0,
#   0.0,
#   2.0,
#   40,
#   23),
#  (311,
#   'DSR772',
#   'TRANSPORTATION DESIGN                              ',
#   'P',
#   'PE',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   20,
#   13),
#  (312,
#   'DSR812',
#   'MEDIA STUDIES                                      ',
#   'D',
#   'PE',
#   3.0,
#   2.0,
#   0.0,
#   2.0,
#   60,
#   21),
#  (313, 'DSS720', 'Independent Study ', 'P', '', 3.0, 0.0, 3.0, 0.0, 30, 1),
#  (314,
#   'DTD899',
#   'DOCTORAL THESIS                                    ',
#   'X',
#   '',
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   5000,
#   2097),
#  (315,
#   'EED854',
#   'MAJOR PROJECT PART 2 (EI)                          ',
#   'P',
#   '',
#   16.0,
#   0.0,
#   0.0,
#   32.0,
#   30,
#   2),
#  (316,
#   'EED898',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   1),
#  (317,
#   'EET410',
#   'PRACTICAL TRAINING                                 ',
#   'P',
#   '',
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   10,
#   2),
#  (318,
#   'ELD411',
#   'B.TECH. PROJECT   I                                ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   100,
#   14),
#  (319,
#   'ELD431',
#   'B.TECH. PROJECT   I                                ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   100,
#   11),
#  (320,
#   'ELD450',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   11),
#  (321,
#   'ELD451',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (322,
#   'ELD452',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (323,
#   'ELD453',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (324,
#   'ELD454',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (325,
#   'ELD455',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (326,
#   'ELD456',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (327,
#   'ELD457',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   1),
#  (328,
#   'ELD458',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (329,
#   'ELD459',
#   'BTP PART II                                        ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   100,
#   0),
#  (330,
#   'ELD780',
#   'MINOR PROJECT                                      ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   60,
#   22),
#  (331,
#   'ELD800',
#   'MINOR PROJECT (EEA)                                ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   0),
#  (332,
#   'ELD802',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   4),
#  (333,
#   'ELD810',
#   'MINOR PROJECT (COMMUNICATION E                     ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   1),
#  (334,
#   'ELD811',
#   'MAJOR PROJECT PART I (COMMUNIC                     ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   0),
#  (335,
#   'ELD812',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   11),
#  (336,
#   'ELD831',
#   'MAJOR PROJECT PART I (INTEGRAT                     ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   1),
#  (337,
#   'ELD832',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   10),
#  (338,
#   'ELD851',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   0),
#  (339,
#   'ELD852',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   9),
#  (340,
#   'ELD871',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   3),
#  (341,
#   'ELD872',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   3),
#  (342,
#   'ELD880',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   '',
#   6.0,
#   0.0,
#   0.0,
#   12.0,
#   60,
#   15),
#  (343,
#   'ELD881',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   60,
#   8),
#  (344,
#   'ELD895',
#   'MS RESEARCH PROJECT                                ',
#   'P',
#   '',
#   36.0,
#   0.0,
#   0.0,
#   72.0,
#   60,
#   20),
#  (345,
#   'ELL100',
#   'INTRO. TO ELECTRICAL ENGG.                         ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   400,
#   455),
#  (346,
#   'ELL201',
#   'DIGITAL ELECTRONICS                                ',
#   'B',
#   '',
#   4.5,
#   3.0,
#   0.0,
#   3.0,
#   350,
#   276),
#  (347,
#   'ELL205',
#   'SIGNALS AND SYSTEMS                                ',
#   'D',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   150,
#   115),
#  (348,
#   'ELL212',
#   'ENGINEERING ELECROMAGNETICS                        ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   150,
#   92),
#  (349,
#   'ELL225',
#   'CONTROL ENGINEERING I                              ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   150,
#   129),
#  (350,
#   'ELL231',
#   'POWER ELECTR. & ENERGY DEVICES                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   150,
#   46),
#  (351,
#   'ELL301',
#   'ELECTRICAL & ELECTRONIC INSTR.                     ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   130,
#   119),
#  (352,
#   'ELL303',
#   'POWER ENGINEERING I                                ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   150,
#   145),
#  (353,
#   'ELL319',
#   'DIGITAL SIGNAL PROCESSING                          ',
#   'M',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   70,
#   33),
#  (354,
#   'ELL332',
#   'ELECTRIC DRIVES                                    ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   67),
#  (355,
#   'ELL365',
#   'EMBEDDED SYSTEMS                                   ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   160,
#   123),
#  (356,
#   'ELL400',
#   'POWER SYSTEMS PROTECTION                           ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   34),
#  (357,
#   'ELL402',
#   'COMPUTER COMMUNICATION                             ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   12),
#  (358,
#   'ELL409',
#   'MACHINE INTELLIGENCE& LEARNING                     ',
#   'J',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   65,
#   66),
#  (359,
#   'ELL411',
#   'DIGITAL COMMUNICATIONS                             ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   120,
#   4),
#  (360,
#   'ELL457',
#   'SPECIAL TOPICS IN COGNITIVE & INTELLIGENT SYSTEMS  ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   4),
#  (361,
#   'ELL703',
#   'OPTIMAL CONTROL THEORY                             ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   23),
#  (362,
#   'ELL705',
#   'STOCHASTIC FILTERING AND IDENT                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   20),
#  (363,
#   'ELL715',
#   'DIGITAL IMAGE PROCESSING                           ',
#   'J',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   150,
#   65),
#  (364,
#   'ELL717',
#   'OPTICAL COMMUNICATION SYSTEMS                      ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   24),
#  (365,
#   'ELL719',
#   'DETECTION & ESTIMATION THEORY                      ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   44),
#  (366,
#   'ELL720',
#   'ADVANCED DIGITAL SIGNAL PROCES                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   14),
#  (367,
#   'ELL723',
#   'BROADBAND COMMUNICATION SYSTEM                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   90,
#   65),
#  (368,
#   'ELL725',
#   'WIRELESS COMMUNICATIONS                            ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   12),
#  (369,
#   'ELL726',
#   'NANOPHOTONICS AND PLASMONICS                       ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   17),
#  (370,
#   'ELL730',
#   'I.C. TECHNOLOGY                                    ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   41),
#  (371,
#   'ELL731',
# ...
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   64),
#  (681,
#   'PYL112',
#   'QUANTUM MECHANICS                                  ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   110),
#  (682,
#   'PYL114',
#   'SOLID STATE PHYSICS                                ',
#   'D',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   60),
#  (683,
#   'PYL202',
#   'STATISTICAL PHYSICS                                ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   56),
#  (684,
#   'PYL204',
#   'COMPUTATIONAL PHYSICS                              ',
#   'J',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   100,
#   57),
#  (685,
#   'PYL302',
#   'NUCLEAR SCIENCE & ENGINEERING                      ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   16),
#  (686,
#   'PYL304',
#   'SUPERCONDUCTIVITY & APPLICAT.                      ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   18),
#  (687,
#   'PYL306',
#   'MICROELECTRONIC DEVICES                            ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   28),
#  (688,
#   'PYL312',
#   'SEMICONDUCTOR OPTOELECTRONICS                      ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   25),
#  (689,
#   'PYL331',
#   'APPLIED QUANTUM MECHANICS                          ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   10),
#  (690,
#   'PYL552',
#   'ELECTRODYNAMICS                                    ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   52),
#  (691,
#   'PYL555',
#   'QUANTUM MECHANICS I                                ',
#   'E',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   8),
#  (692,
#   'PYL556',
#   'QUANTUM MECHANICS II                               ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   50),
#  (693,
#   'PYL558',
#   'STATISTICAL MECHANICS                              ',
#   'F',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   54),
#  (694,
#   'PYL560',
#   'APPLIED OPTICS                                     ',
#   'H',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   53),
#  (695,
#   'PYL563',
#   'SOLID STATE PHYSICS                                ',
#   'D',
#   '',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   60,
#   53),
#  (696,
#   'PYL651',
#   'ADVANCED SOLID STATE PHYSICS                       ',
#   'C',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   35,
#   6),
#  (697,
#   'PYL659',
#   'LASER SPECTROSCOPY                                 ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   21),
#  (698,
#   'PYL704',
#   'SC. & TECHNOLOGY OF THIN FILMS                     ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   43),
#  (699,
#   'PYL705',
#   'NANOSTRUCTURED MATERIALS                           ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   36),
#  (700,
#   'PYL707',
#   'CHARACTERISATION TEC. FOR MAT.                     ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   27),
#  (701,
#   'PYL725',
#   'SURFACE PHYSICS AND ANALYSIS                       ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   30),
#  (702,
#   'PYL726',
#   'SEMICONDUCTOR DEVICE TECHNOLOGY                    ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   16),
#  (703,
#   'PYL727',
#   'ENERGY MATERIALS AND DEVICES                       ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   17),
#  (704,
#   'PYL742',
#   'GEN. RELATIVITY & INTRO. ASTR.                     ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   38),
#  (705,
#   'PYL743',
#   'GROUP THEORY & ITS APPLICATION                     ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   66),
#  (706,
#   'PYL744',
#   'HIGH ENERGY PHYSICS                                ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   31),
#  (707,
#   'PYL746',
#   'NON EQUILIBRIUM STATISTICAL ME                     ',
#   'L',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   14),
#  (708,
#   'PYL748',
#   'QUANTUM OPTICS                                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   26),
#  (709,
#   'PYL752',
#   'LASER SYSTEMS AND APPLICATIONS                     ',
#   'J',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   27),
#  (710,
#   'PYL756',
#   'Fourier Optics and Holography ',
#   'L',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   31),
#  (711,
#   'PYL760',
#   'BIOMEDICAL OPTICS & BIO PHOTO.                     ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   35),
#  (712,
#   'PYL762',
#   'STATISTICAL OPTICS                                 ',
#   'A',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   20),
#  (713,
#   'PYL770',
#   'ULTRA FAST OPTICS & APPLICATI.                     ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   24),
#  (714,
#   'PYL772',
#   'PLASMONIC SENSORS                                  ',
#   'K',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   9),
#  (715,
#   'PYL780',
#   'DIFFRACTIVE AND MICRO OPTICS                       ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   17),
#  (716,
#   'PYL792',
#   'OPTICAL ELECTRONICS                                ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   26),
#  (717,
#   'PYL800',
#   'NUM. & COMP. METH. IN RESEARCH                     ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   61),
#  (718,
#   'PYL879',
#   'SELECTED TOPICS IN APPLIED OPT                     ',
#   'X',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   1),
#  (719,
#   'PYL891',
#   'FIBER OPTIC COMPONENTS AND DEVICES                 ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   16),
#  (720,
#   'PYP100',
#   'PHYSICS LABORATORY                                 ',
#   'Q',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   100,
#   459),
#  (721,
#   'PYP212',
#   'ENGG. PHYSICS LABORATORY II                        ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   100,
#   47),
#  (722,
#   'PYP222',
#   'ENGINEERING PHYSICS LAB.   IV                      ',
#   'Q',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   100,
#   56),
#  (723,
#   'PYP562',
#   'LABORATORY II                                      ',
#   'Q',
#   '',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   60,
#   51),
#  (724,
#   'PYP702',
#   'SOLID STATE MATERIALS LABORATORY II                ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   20),
#  (725,
#   'PYP762',
#   'ADVANCED OPTICS LABORATORY                         ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   17),
#  (726,
#   'PYP764',
#   'ADVANCED OPTICAL WORKSHOP                          ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   1),
#  (727,
#   'PYQ303',
#   'SEMINAR COURSE   III                               ',
#   'Q',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   100,
#   76),
#  (728,
#   'PYS300',
#   'INDEPENDENT STUDY                                  ',
#   'X',
#   '',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   100,
#   2),
#  (729,
#   'RDD750',
#   'MINOR PROJECT                                      ',
#   'Q',
#   'OE',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   20,
#   1),
#  (730,
#   'RDL700',
#   'BIOMAS PRODUCTION                                  ',
#   'J',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   49),
#  (731,
#   'RDL701',
#   'RURAL INDUSTRIALISATION POLICES PROGRAMMES & CASE  ',
#   'E',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   99),
#  (732,
#   'RDL710',
#   'RURAL INDIA AND PLANNING FOR DEVELOPMENT           ',
#   'J',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   65),
#  (733,
#   'RDL722',
#   'RURAL ENERGY SYSTEMS                               ',
#   'F',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   100,
#   102),
#  (734,
#   'RDL726',
#   'HERBAL,MEDICINAL ANDAROMATIC PRODUCTS              ',
#   'M',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   30,
#   30),
#  (735,
#   'RDL740',
#   'TECHNOLOGY OF UTILIZATION OF WASTELANDS & WEEDS    ',
#   'AA',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   44),
#  (736,
#   'RDL760',
#   'FOOD QUALITY AND SAFETY                            ',
#   'J',
#   'OE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   55),
#  (737,
#   'RDP750',
#   'BIOMASS LABORATORY                                 ',
#   'Q',
#   'OE',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   20,
#   13),
#  (738,
#   'RDQ301',
#   'SEMINAR COURSE   I                                 ',
#   'X',
#   'OE',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   32),
#  (739,
#   'RDQ302',
#   'SEMINAR COURSE   II                                ',
#   'X',
#   'OE',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   33),
#  (740,
#   'RDQ303',
#   'SEMINAR COURSE   III                               ',
#   'X',
#   'OE',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   34),
#  (741,
#   'RDQ304',
#   'SEMINAR COURSE IV                                  ',
#   'X',
#   'OE',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   31),
#  (742,
#   'RDQ305',
#   'SEMINAR COURSE V                                   ',
#   'X',
#   'OE',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   30,
#   44),
#  (743,
#   'SBC796',
#   'GRADUATE STUDENT SEMINAR II                        ',
#   'P',
#   '',
#   0.5,
#   0.0,
#   0.0,
#   1.0,
#   60,
#   13),
#  (744,
#   'SBD301',
#   'MINI PROJECT                                       ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   10,
#   3),
#  (745,
#   'SBD895',
#   'MS RESEARCH PROJECT                                ',
#   'P',
#   '',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   60,
#   5),
#  (746,
#   'SBL100',
#   'INTRO. TO BIOLOGY FOR ENGINEER                     ',
#   'C',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   600,
#   402),
#  (747,
#   'SBL201',
#   'HIGH DIMENSIONAL BIOLOGY                           ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   14),
#  (748,
#   'SBL701',
#   'BIOMETRY                                           ',
#   'M',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   10),
#  (749,
#   'SBL703',
#   'ADVANCED CELL BIOLOGY                              ',
#   'H',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   50,
#   14),
#  (750,
#   'SBL704',
#   'HUMAN VIROLOGY                                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   12),
#  (751,
#   'SBL705',
#   'BIOLOGY OF PROTEINS                                ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   19),
#  (752,
#   'SBL714',
#   'PLANT BIOTECH. & HUMAN HEALTH                      ',
#   'F',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   1),
#  (753,
#   'SBL720',
#   'GENOME AND HEALTHCARE                              ',
#   'B',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   60,
#   5),
#  (754,
#   'SBP200',
#   'INTRODUCTION TO PRACTICAL MODERN BIOLOGY           ',
#   'Q',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   60,
#   7),
#  (755,
#   'SBS800',
#   'INDEPENDENT STUDY                                  ',
#   'Q',
#   '',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   10,
#   1),
#  (756,
#   'SBV750',
#   'BIOINSPIRATION AND BIOMIMETICS                     ',
#   'K',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   60,
#   21),
#  (757,
#   'SBV884',
#   'ELEMENTS OF NEUROSCIENCE                           ',
#   'J',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   60,
#   8),
#  (758,
#   'SID880',
#   'MINOR PROJECT IN INFORMATION TECHNOLOGY            ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   30,
#   0),
#  (759,
#   'SID890',
#   'MS RESEARCH PROJECT                                ',
#   'P',
#   '',
#   40.0,
#   0.0,
#   0.0,
#   80.0,
#   30,
#   4),
#  (760,
#   'SIL765',
#   'NETWORKS & SYSTEM SECURITY                         ',
#   'B',
#   '',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   40,
#   33),
#  (761,
#   'SIV895',
#   'SPECIAL MODULE ON INTELLIGENT INFO. PROCESSING     ',
#   'P',
#   '',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   30,
#   1),
#  (762,
#   'TTC410',
#   'COLLOQUIUM (TT)                                    ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   3.0,
#   0.0,
#   30,
#   2),
#  (763,
#   'TTT410',
#   'PRACTICAL TRAINING                                 ',
#   'P',
#   '',
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   10,
#   2),
#  (764,
#   'TXD357',
#   'MINOR DESIGN PROJECT   VII                         ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   120,
#   1),
#  (765,
#   'TXD358',
#   'MINOR DESIGN PROJECT VIII                          ',
#   'P',
#   '',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   120,
#   1),
#  (766,
#   'TXD401',
#   'MAJOR PROJECT PART I                               ',
#   'P',
#   'DC',
#   4.0,
#   0.0,
#   0.0,
#   8.0,
#   120,
#   14),
#  (767,
#   'TXD402',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   '',
#   8.0,
#   0.0,
#   0.0,
#   16.0,
#   120,
#   19),
#  (768,
#   'TXD803',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   22),
#  (769,
#   'TXD804',
#   'MAJOR PROJECT PART II                              ',
#   'P',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   15),
#  (770,
#   'TXD806',
#   'MAJOR PROJECT PART II (TCP) ',
#   'P',
#   'PC',
#   12.0,
#   0.0,
#   0.0,
#   24.0,
#   30,
#   10),
#  (771,
#   'TXL211',
#   'STRUCTURE & PHYSICAL PROPERTIE                     ',
#   'D',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   125),
#  (772,
#   'TXL221',
#   'YARN MANUFACTURE I                                 ',
#   'E',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   109),
#  (773,
#   'TXL231',
#   'FABRIC MANUFACTURE I                               ',
#   'B',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   119),
#  (774,
#   'TXL241',
#   'TECH. OF TEXT. PREPARATION & F                     ',
#   'F',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   129),
#  (775,
#   'TXL361',
#   'EVALUATION OF TEXTILE MATERIAL                     ',
#   'D',
#   'DC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   120,
#   92),
#  (776,
#   'TXL371',
#   'THEORY OF TEXTILE STRUCTURES                       ',
#   'C',
#   'DC',
#   4.0,
#   3.0,
#   1.0,
#   0.0,
#   120,
#   123),
#  (777,
#   'TXL372',
#   'SPECIALITY YARNS AND FABRICS                       ',
#   'J',
#   'DC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   120,
#   97),
#  (778,
#   'TXL714',
#   'ADVANCED MATERIALS CHARACTERIZATION TECHNIQUES     ',
#   'P',
#   'PC',
#   1.0,
#   1.0,
#   0.0,
#   0.0,
#   75,
#   40),
#  (779,
#   'TXL715',
#   'TECHNOLOGY OF SOLUTION SPUN FIBRES                 ',
#   'B',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   75,
#   17),
#  (780,
#   'TXL725',
#   'MECHANICS OF SPINNING MACHINES                     ',
#   'A',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   18),
#  (781,
#   'TXL740',
#   'SC. & APP. OF NANOTEC. IN TEX.                     ',
#   'E',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   77),
#  (782,
#   'TXL748',
#   'ADVANCES IN FINISHING OF TEXTILES                  ',
#   'F',
#   'PC',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   40,
#   30),
#  (783,
#   'TXL754',
#   'SUSTAINABLE CHEMICAL PROCESSING OF TEXTILES        ',
#   'B',
#   'PC',
#   2.0,
#   2.0,
#   0.0,
#   0.0,
#   40,
#   11),
#  (784,
#   'TXL756',
#   'TEXTILE AUXILIARIES                                ',
#   'J',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   13),
#  (785,
#   'TXL766',
#   'DE. & MANUF. OF TEXT. STR. CO.                     ',
#   'B',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   69),
#  (786,
#   'TXL771',
#   'ELECTRONICS AND CONTROLS FOR TEXTILEINDUSTRY       ',
#   'J',
#   'PE',
#   4.0,
#   3.0,
#   0.0,
#   2.0,
#   65,
#   54),
#  (787,
#   'TXL775',
#   'TECHNICAL TEXTILES                                 ',
#   'D',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   57),
#  (788,
#   'TXL777',
#   'PRODUCT DESIGN AND DEVELOPMENT                     ',
#   'H',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   27),
#  (789,
#   'TXL782',
#   'PRODUCTION & OPERATIONS MGMT                       ',
#   'F',
#   'PE',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   53),
#  (790,
#   'TXL783',
#   'DESIGN OF EXPER. & STAT. TECH.                     ',
#   'E',
#   '',
#   3.0,
#   3.0,
#   0.0,
#   0.0,
#   65,
#   71),
#  (791,
#   'TXP212',
#   'MANUFACTURED FIBRE TECHNO. LAB                     ',
#   'C',
#   'DC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   97),
#  (792,
#   'TXP221',
#   'YARN MANUFACTURE LABORATORYI                       ',
#   'E',
#   'DC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   108),
#  (793,
#   'TXP231',
#   'FABRIC MANUFACTURE LAB.   I                        ',
#   'B',
#   'DC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   112),
#  (794,
#   'TXP241',
#   'TECH. OF TEX. PRE. & FIN. LAB.                     ',
#   'F',
#   'DC',
#   1.5,
#   0.0,
#   0.0,
#   3.0,
#   120,
#   117),
#  (795,
#   'TXP361',
#   'EVALUATION OF TEXTILES LAB                         ',
#   'D',
#   'DC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   92),
#  (796,
#   'TXP716',
#   'Fibre Production and Post Spinning Operation Laboratory ',
#   'F',
#   'PE',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   65,
#   17),
#  (797,
#   'TXP725',
#   'MECHANICS OF SPINNING MACHINES LAB                 ',
#   'P',
#   'PC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   40,
#   18),
#  (798,
#   'TXP748',
#   'TEXTILE PREPARATION AND FINISHING LAB              ',
#   'P',
#   'PC',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   25,
#   17),
#  (799,
#   'TXP761',
#   'EVALUATION OF TEXTILE MATERIALS                    ',
#   'C',
#   'PC',
#   2.0,
#   0.0,
#   0.0,
#   4.0,
#   75,
#   19),
#  (800,
#   'TXQ302',
#   'SEMINAR COURSE 2                                   ',
#   'P',
#   '',
#   1.0,
#   0.0,
#   0.0,
#   2.0,
#   120,
#   128),
#  (801,
#   'VED750',
#   'MINOR PROJECT                                      ',
#   'P',
#   '',
#   3.0,
#   0.0,
#   0.0,
#   6.0,
#   60,
#   0),
#  (802,
#   'VEL700',
#   'HUMAN VALUES AND TECHNOLOGY                        ',
#   'M',
#   '',
#   3.0,
#   2.0,
#   1.0,
#   0.0,
#   60,
#   54)]
